# %%
import numpy as np


# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115393 characters, 65 unique.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


class CharGRUOneHot(nn.Module):
    """
    A GRU that takes one-hot inputs of shape (batch, seq_length, vocab_size).
    No embedding layer is used.
    """
    def __init__(self, vocab_size, hidden_size=512):
        super().__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        
        # GRU expects input_size = vocab_size (since one-hot dimension)
        # batch_first=True => input shape (batch, seq_length, vocab_size)
        self.gru = nn.GRU(input_size=vocab_size, hidden_size=hidden_size,
                          num_layers=2, batch_first=True)
        
        # Map hidden states to vocab-size logits
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, hidden=None):
        """
        x: (batch, seq_length, vocab_size) => one-hot vectors
        hidden: (1, batch, hidden_size) initial hidden state
        returns: (logits, hidden)
          logits shape: (batch, seq_length, vocab_size)
        """
        # Pass x directly to GRU (no embedding)
        # output => (batch, seq_length, hidden_size)
        # hidden => (2, batch, hidden_size)
        output, hidden = self.gru(x, hidden)
        
        # Map to vocab logits
        # shape => (batch, seq_length, vocab_size)
        logits = self.fc(output)
        
        return logits, hidden
    
    def init_hidden(self, batch_size=1):
        """ Return a fresh hidden state of shape (2, batch_size, hidden_size). """
        return torch.zeros(2, batch_size, self.hidden_size)

# %%
def indices_to_onehot(indices, vocab_size):
    """
    indices: shape (batch, seq_length), dtype long
    returns: float tensor of shape (batch, seq_length, vocab_size)
    """
    # F.one_hot => (batch, seq_length, vocab_size) with dtype=int
    one_hot = F.one_hot(indices, num_classes=vocab_size)
    return one_hot.float()

# %%
def sampleGRU(model, hidden, start_ix, length, vocab_size, ix_to_char):
    """
    model: Your CharGRUOneHot instance
    hidden: initial hidden state (shape [1, batch=1, hidden_size])
    start_ix: integer index of the first character
    length: how many characters to generate
    vocab_size: total number of possible chars
    ix_to_char: mapping int -> character (for final text)
    returns: a string of generated characters
    """

    # We'll store the generated characters' indices
    generated_indices = []
    # current input char index
    char_ix = start_ix

    # We do a loop for 'length' steps
    for _ in range(length):
        # Build a one-hot input of shape (batch=1, seq_len=1, vocab_size)
        x_onehot = torch.zeros((1, 1, vocab_size))
        x_onehot[0, 0, char_ix] = 1.0

        # Forward pass (no grad)
        with torch.no_grad():
            logits, hidden = model(x_onehot, hidden)
            # logits shape => (1, 1, vocab_size)

        # Take the last time-step => shape (vocab_size,)
        probs = F.softmax(logits[0, 0], dim=-1).cpu().numpy()
        # Sample from the probability distribution
        char_ix = np.random.choice(vocab_size, p=probs)
        
        generated_indices.append(char_ix)

    # Convert all indices to characters
    generated_text = ''.join(ix_to_char[ix] for ix in generated_indices)
    return generated_text

# %%
# Suppose you have:
# data_indices: a long list of integers in [0, vocab_size-1]
# vocab_size: total number of unique chars
# idx_to_char, char_to_idx: optional for sampling

model = CharGRUOneHot(vocab_size, hidden_size=512)
criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = optim.Adam(model.parameters(), lr=1e-3)

seq_length = 25
pointer = 0
n = 0
max_iters = 44700 * 100 # 100 times pass the full text 
smooth_loss = 0.0

# init hidden state for single-batch
hidden = model.init_hidden(batch_size=1)

while True:

    # if we near end of data, wrap around
    if pointer + seq_length + 1 >= len(data):
        pointer = 0
        hidden = model.init_hidden(batch_size=1)
    
    # Grab chunk of length seq_length
    input_seq = [char_to_ix[ch] for ch in data[pointer:pointer+seq_length]]
    target_seq = [char_to_ix[ch] for ch in data[pointer+1:pointer+seq_length + 1]]

    # Convert to tensors, shape => (1, seq_length)
    inputs_t = torch.tensor(input_seq, dtype=torch.long).unsqueeze(0)
    targets_t = torch.tensor(target_seq, dtype=torch.long).unsqueeze(0)

    # Convert input_seq to one-hot => shape (1, seq_length, vocab_size)
    x_onehot = indices_to_onehot(inputs_t, vocab_size=vocab_size)
    
    optimizer.zero_grad()
    # forward pass
    logits, hidden = model(x_onehot, hidden)
    
    # shape => (1, seq_length, vocab_size)
    # Flatten so cross-entropy can be computed:
    #  => logits: (1*seq_length, vocab_size), targets: (1*seq_length)
    loss = criterion(logits.view(-1, vocab_size), targets_t.view(-1))
    
    
    loss.backward()
    optimizer.step()

    hidden = hidden.detach()

     # smooth loss
    smooth_loss = 0.99 * smooth_loss + 0.01 * loss.item()
    
    if n % 100 == 0:
        print(f"Iter {n}, smooth_loss={smooth_loss:.4f}")
        # Optional: sample from model...
        print(sampleGRU(model, hidden, input_seq[0], 200, vocab_size, ix_to_char))
    
    pointer += seq_length
    n += 1
    
    if n == max_iters: 
        break
# Out:
# Iter 0, smooth_loss=1.0433
# tNSRx!GY.SX,!nrO'vsMdx;e-&VZ-UheUYyH$b.'p
# geAHz?Q,PYBISXN3ICGSQDPyGz.LGhUVfPpLpsoMEBsD:$OpX
# Fh:OteB,s,3?Ld3AXnFDgWhbYlfaA&ghWtL:tp3H fCGV,M!kj.$ehj?aJXUmDLD!V!lbKzvJy;ikZ;ezB
# &-pctghsp$BWNEug!.ierYFSN
# Iter 100, smooth_loss=49.7249
# es cae fo re .l:? ooe
# iinl Cotd &Ier
# rh :hatrs tioe
#  oae etds woCt o iarrt loed so, ywpe Cny? o yhtllp
# etnss wros trh s:ihot le lLarinn hwaen-rtih o'dst Aerr
# tinw newomeSntwrls? in hit oto: re;scsl
# Aa
# Iter 200, smooth_loss=60.9455
# r oenousmathe apfsskthe thikb un:onEmoentathuslsa;es,, autblatelent, nhtsetad, sir thecthef,t
# Tale pooc
# kod efoo. ne, yore.
# Sotg tat aRinlued, a' tos merinsd serhtus, mit gef aarkle aour, repeitictobe
# Iter 300, smooth_loss=60.4785
# lpale ousgingano?
#
# Fertou:
# Iu wasgoss:
#
# MEEENUISS
# Rou' yo; Wane',
# thaupby
# TeoeE,
# In
# Wore pathe
#
# MECENNSU:
#
# MECENjIS
# The;:
# Fativeu-d
# Thas ti he bokp whe yaRenwoulehe.
#
# MEIEUUS
# Mhous thepare wheal.
# Aus?
# Iter 400, smooth_loss=60.4516
# on no Thargerwot Whe aans thaC rhoub thou; himune,
# Bth sms! ontiron on fhun ee laB ku ar goup meon-
# D'nd The ib..
#
# MNENIUU::
#
# MARCIUI:
# S't,
# Theour untizekice ibk fit I
# S:uct heud theoridi
# hoh cam ea,
# Iter 500, smooth_loss=58.9061
# ero angt' hifell,
#
# SITiOm.
# SIIIUB:
# Bugh t, fe caly ther.
#
# BRUTUS:
# Whacro
# Whe &aceoninmisiut af ot acitish hin
# ne, an Cimist yo te caclas, cinkate
# The gedI bthims das cithe st maklacg tomerchr ande,
# fr
# Iter 600, smooth_loss=58.6269
# t Malcce moweled is reas pfon on of Woll wyou sa, shiter.
# SeFs. t ond is to lp wur d won noon,
# 'f bl spn meroure renwe y he these nathe fhmes un sin
#
# RUNI
# Sengour call fhe fomir in theve henchoulmhew
# Iter 700, smooth_loss=58.9765
#  axWe an'dy hond:an, afferl? hathing thiuk
# s a'd a kou y ar; ast igs, im aterfir hipnfed bes, cowrthan. ondd tha hin oos. I IMllwpes lyearss the ander s oul!eze the ermy thce ele svy h lwwargit han n.
# Iter 800, smooth_loss=54.5540
# elador, s.  MorEUY:.
#
# : go enet.  on gowis.
#
# MARRIUS:
# Se, movey.
#
# H,, bre. the tould.
#
# MARRUS:
# Cowele neog, beaver ho, mt ut bed, tues, werhive,
# , wespe, thys.
# 'r!
# wethus teieeaS,
# the he t' wol..'at.
#
# Iter 900, smooth_loss=54.1925
#
#
# MARTIUS:
# All ert, the a fart s faowst er.
# frolds.
#
# RARTIUS:
# Taee hithe'll com-Asou,
# Siuchelp,
#
# ArcussfLark: Sow, the the, dieg,s, the, ard the or it, ares tie shis pithe,.
# Llict am storlis:
# Hores,
# Iter 1000, smooth_loss=54.5925
# ugs.
# Os,
# Gould hithel: condich how corvingucwanse, Marish,
# Woungsw;
# I veand and of voulenPs, I tius goed o, hith bets seil, wouvir ath
# Whar dy thond
# Thius
# ca'r gupkce comancs are comn'niwe gicto ?d an
# Iter 1100, smooth_loss=52.3621
# Ther cots, and wo'de Larst.
#
# CARCIUS:
# Ses tolve rinttse as matere tme inimide I ongs with sust, ong batithis;
# Asgest invoue they, as thes searlersing wos our on yat I wanpdar.
# MARCIUS:
# A; se trengy a
# Iter 1200, smooth_loss=52.3096
# now
# Dats ne atery,
# Whel ill so tyie sh
# Yulc are sorem of he txsered, wa thy micit.
#
# LARTIUS:
# Of theere sein,
# In hatvibland,
# OThamen,
# Fremes is your ast atells.
#
# ucF I hare thisf fenCdiers: meae the p.
# Iter 1300, smooth_loss=52.7048
# r.
#
# CORIAIUS:
# MARCIUSe
# Hield lavime MiRCI
# AUF'ch hamon
# Whon slus I siRE ay pofarsNy ke!,
# As thic,
#
# COMINIUS:
# Seits not, nof,
# MARCIUSUSUS MMRAIUS:
# As tham bis?-
# Lad thand sogct,
# What carsiok nofle whes
# Iter 1400, smooth_loss=52.8909
#  Ro mand hat himshban:
# We hs moreimind lord cun; fuchith st dould,
# ; miss'pter poest the potte hy berter:
# Se you so stere'd us thall'ceedf of hy where
# Gake is thatr Lathe so stor bading mer yue;
# He I
# Iter 1500, smooth_loss=51.6023
# e ich in ghat me thy shullith manan cikp whe seincprening
# Cimerieng.
#
# fwCINIUS:
# With a the i'stant in mond thly hacu nat
# An'of and amen me a blevor.
# Bot goonh the prondry to Had I lote anRsunitht'ngo
# Iter 1600, smooth_loss=51.4087
# ee mealo: norerd, go daarike so,
# bormy,-Cathoughing med knousiy four him,
# Martutie, some-Yours prois, Mascius, wore, houdht besgent; be one whoushang
# thoes
# prom!
# your and an sorer
# Majmios, you hesade
#
# Iter 1700, smooth_loss=50.2855
# ne wornditiolinal.
#
# MENELIUS:
# Hone apl at he
# lrorind.
#
# MENENIUS:
# Thinen thene benow, thim hime!
#
# VOLUMNIA:
# With tnall Ay I! the Qith, whand daije that and in him purepy:
# Then taon,
# ne'll nole an thend
# Iter 1800, smooth_loss=51.4199
# rver's puncelion tid thaur vee wichowss comssos ccamso, reeds bupir;
#
# COMINIUS:
# Thie cheace won o worsleonn in rommeing
#
# MlNENIUS:
# The elcamm whe we ghat chim in heme-- arrer allad epidle pwintveim:
# C
# Iter 1900, smooth_loss=49.0332
# ias;
# Ufon exfut
# Thime
# Athe thuie the mare: you,
# I; ane peave ceart for love, ;ankores, come.
# Hather.
#
# SeCsiRoOUS: came the rentonk:
# A dave meiph capare filet forsion,.
#
# at ITIAs: of mecair fares 'tvee
# Iter 2000, smooth_loss=48.6397
#  a
# niss hanNhanglgice se doublies olenours, a, remeringre
# Masthers
# Indy Comirenhice
# It to of haer oursternemies as ourin cerbther
# First bon tharce our a do dester that his'
# He reast proll  of hem; ent
# Iter 2100, smooth_loss=49.9068
# uldeds and lostee-
# Bphow stiel: lak feate be blond co'nd diates snat,
# When ntics nit
# A'd ieETortion stoll ufay liged'd'ded and hiss marte'd
# Timped this of the sawed werxeforT.
# Befterted
# oppur the blic
# Iter 2200, smooth_loss=46.4176
# loces four oued, thir; he requiial then we of you
# Sake our the leovereseld ig.
#
# Seiw, I wound yeurm, to dise'd shol.N
# You enould gowf at if i pre:all.
#
# Senate wirk widh s'opll.
#
# TrkteAle:
# Hisumarc-itC
# Iter 2300, smooth_loss=47.3318
# aves stoue!
# Shearts of heme houldn.
#
# You we him suegct and them' make, Rome dulle: by by goverblines;
# Pon mont? at my hous, give usstrem.
# SECINIUS:
# Say'd for nobring mume sulFicn,
# Ehe tome mak: we no
# Iter 2400, smooth_loss=44.2445
# op keeple your gog vood not sow, I will dive fore your; preeth, and choin
# givy be consurt veicuss,
# to be postelt;
# Whith pipir. I cay, bee detorg tued not yor,
# I voicceiCs oncn Citizen:
# Your coutt ma
# s
# Iter 2500, smooth_loss=43.1325
# have.
#
# Loukh CinisUS:
# Anow witly,
# Hhat had bik matks
# Wid hus hemedd us do i' shon us his we not
# the poople nours loidst; alan ictf and se: counds
# frire-his 'es housd hiv.'d I love countel.
#
# Sicius his
# Iter 2600, smooth_loss=45.0573
# s to ang tgee to begcef?
# At thongat of now arvine yhed dd beaikeenthus, endert.
#
# BRUTUS:
# The hespormI Of their agees you noble poarece
# Havien; the aif to cisserf of'ch his beove-aint
# He had cain thrim
# Iter 2700, smooth_loss=45.2332
#  dyo.
#
# CORIOLANUS:
# Sur, po'de the told: he to ther onfide:
# Orsted m'd as themVand to headg a brange he:
# And the Marciss to soR;, Bet. time acas weve
# The uson uus agar.
# Whald them hid mase of which now
# Iter 2800, smooth_loss=42.2935
# iem?
#
# CORIOLANUS:
# You, a plobian swill I, yot
# But re was pispowh are whis much are iftinn consul.
#
# CIRIOLANUS:
# Now a servand Norm with a potWire
# Whire sum.
#
# CORIOLANUS:
# Not I dives
# Nor uplice ou he yo
# Iter 2900, smooth_loss=45.2503
# end whoch such grates boly; to sope, of af is gron,
# In a countois thus hoar't, thee I make 'gaw!
# The beare shaud counsleb here, potess be to the ross.
#
# ThindoSe potake
# We sake on to goved change
# That
# Iter 3000, smooth_loss=46.1757
# r, foth as to sat deither the woll's.
#
# TORIOLANUS:
# How
# Thenen wheles on!
# Whereect the preince fosh one o' thin sttoth.
#
# CORIOLANUS:
# Call theseet a thereer's. How, frenchsuse
# Mons for o't,
# Ot dismerce
# Iter 3100, smooth_loss=44.3450
# iEges all theurt'y
# Trubunen.
#
# SICINIUS:
#
# AEtius,
# Youe reang us, thenem
# And oprous abont him; Which, haid tind,
# And wet is oflest buim beards be ore are the piring.
#
# BRUTUS:
#
# BRUTUS:
# Your him, Riy, Mec
# Iter 3200, smooth_loss=43.2719
# re mes the the sore Marcius.
#
# CIOINOLSNANPiSUn:
# He shall he swar's a were spoupar
# And would the gan wim, the war' the requarbatity.
#
# MENENIUS:
# Cay, ristlef mantry: wherercestrpews hould nepe chay dose
# Iter 3300, smooth_loss=44.7834
# lk'd a swoWher, in a gansulies,
# We ear us, thy loves this were and proald tietile:
# Him us.y
# Lake is the geable'd da goath;--
#
# BRUTUS:
# Snot took lams to that breneed before.
#
# CiblitUS:
# Cons'l:
# In hall
# Iter 3400, smooth_loss=42.9339
# r, and there?
#
# CORIOLANUS:
# I would buf you say.
#
# CORIOLANUS:
# I foon I
# Thith a tarphow
# What yitle best thes:
# Showll the wllis parceusenst pity.
#
# BRUTUS:
# For shave fratitad:
# Your fallitgun enak a but th
# Iter 3500, smooth_loss=43.9553
# the eise feaile thene aste hens woldsey warss; munes bit:ront,
# I was their, heart
# Than farponer,
# But a brun like hushall him.
#
# MENENIUS:
# Thou have my furtre of not beeng afking e'd
# Thilgan leyis exelf
# Iter 3600, smooth_loss=45.0647
# iss'd Bed I by the pocims, stir.
#
# MENENIUB:
# The hid the blesorm
# Of furnt uf
# And I sayd his inspetterare You this in pilten:
#
# MENENIUS:
# A mu'd for the hone as you then, More to thim atwild mar heic,
# Yo
# Iter 3700, smooth_loss=42.9223
#  sigutuder; and goefor?
#
# COMINIUS:
# Conhand all dy upon vililys I bither, ards that of you suncusons
# 'VOLUMNIA:
# That hereds beine and cerpantys for calline.
#
# AEdile:
# I do canserf!
#
# BIUk:
# sull.
# Dear the
# Iter 3800, smooth_loss=42.0371
#  sFratire
# Have make reake, hearhs prock as
# The enange,--
#
# COMINIUS:
# Taye 'tmmoution my fre
# Estions, and deand:
# I dather, seet
# Traitaich or the prosen; dishant
# Tromeg-not again ramite,
# Truon Ending--
# I
# Iter 3900, smooth_loss=44.7038
# .
#
# AEdol:
# Nay, atten, in
# Give he'd ay beinrs, this werverce,
# Of shere uncwetity, I no: Putizens!
#
# CORIOLANINIA:
# I al yeo! used bearion;
# Sham! one gree
# Gorer have you noie, bates you hear,
# And speak ot
# Iter 4000, smooth_loss=43.3531
# IUS:
# Hear saech, meak: in peowe.
# O, they foom with, a can?
# Liks o' they
# You swall bodnons!
# MRNEOIUS:
# By seadt, whie. I home, swall ay to some haght.
#
# SIRIILIA:
# Axhithou shall heals.
#
# VOMUMNIA:
#
# VOLUM
# Iter 4100, smooth_loss=43.1883
# erst one hear?
#
# Roman:
# I enderth bece xade some. Nip, youell sir: the putpe the wath this; would you.b
# Of then enge, anke will plain there madian watlitile benorous of the txo firm the his gions;
# me o
# Iter 4200, smooth_loss=44.1514
# es hoars and it,
# And us tere, and meess,
# And elace, and wsont
# Thoupare blaok. His house noble-'llows,
# Thoue heart
# Oot worh vouse of elaise,
# As their, knoblous.
# Will, be worldest,
# To be diven whose whi
# Iter 4300, smooth_loss=39.3797
#  I ICINIUS:
# Now kisestest, lich.
#
# CORIOLANUS:
# Pran you ?ld mistrat I hrangle's fracest mands,tw me,
# Whenws mast proke prate wnot his samsten, batter bufakes him
# Casy;
# CotionT manhan,; no mark.
#
# MEtEoI
# Iter 4400, smooth_loss=42.4434
# hee an prome 'bRimad! asle groid of blood in, Comiulaous
# broce my ruarchiacnes--Mast plich anger
# Standion.
#
# CORIOLANUS:
# Helf I' thee uslengly
# As, and ssape fondest ploest mont comunce,
# Let me thy cino
# Iter 4500, smooth_loss=41.7649
# emed.
#
# First Sorveng andran--
# Your for the yethe woNst ut By were your
# Streneth her, hed ceming he him for in bers that ius pres mome meder I hat in
# Ro, in than I thome it ig?
# Whis hould take ween fim
# Iter 4600, smooth_loss=40.3499
# ood, then? which: him and their but all, they say
# thes frianncn; if shill of beto; like
# miw; sreis of tuest wealsor' their strirth he would aplies;
# Ins you, save as
# That
# wath lifs of that? -wirst the
#
# Iter 4700, smooth_loss=41.7552
# il ro'nst
# I do you tain, his trever whe roo
# selvest buct inservies ape,
# Sided in not.
#
# Citizens:
# Led, well,
# O wake with cone-then that with as What,
# Nave whothing caneation, is crmentours, and bsopup
# Iter 4800, smooth_loss=41.5796
# rm'd tire would feant.
#
# Second Mefanidy:
# Now arnot ter Marcius,-'s
# If your of your vine that to wake.
#
# MENENIUS:
# Where's they
# Heart do-h your's nagomee tengied: is worthy;
# Yourmay nother?
#
# BRUTUS:
# Jea
# Iter 4900, smooth_loss=42.0717
#  nerricians:
# O  hepolich
# And in, and us a exerces.
#
# Second Arning Tham, I'll will puriter?
#
# MENENIUS:
# I warfer dem: hole.
#
# COMINIUS:
# O'rvess it!
#
# MENENIUS:
# The upon a go wiph
# Ar had all not af it. Coi
# Iter 5000, smooth_loss=42.4491
# icurs to too hours not so'ling,
# As I teing all love dirsouncees
# As as for thou this shall at our dews drian: for all the knest war; I dad bane the fitly
# Hell'll the robshered be home.
# You him to him t
# Iter 5100, smooth_loss=43.3938
# olk of feal:
# You noself in a town, but, know erp pity, breake thet
# To pryoil,---he said of foob
# We noble so tele troby,
# For his fefonour ose to the rave a praither tee this say them
# A risure to nooe a
# Iter 5200, smooth_loss=40.5858
#  my propler menst.
#
# First Senator:
# Frel his poor to before.
#
# Third Senator:
# Rot you meake as I'll werly ansute?
#
# AUFIDIUS:
# Dinfline me; let' lears gain to bear.
#
# First Senaton:
# St otCitizen:
# And to ca
# Iter 5300, smooth_loss=40.9342
# ver.
#
# COMINIUS:
# Nith tell me forthan, you carnot proparon,
# As the alfers? but peace, bfiends,---
#
# S you cannot farey; fellow, remiss:
# The mean
# shall some the gecare from your glaas ronank
# have mack. k
# Iter 5400, smooth_loss=40.7375
# port
# whom his worthy
# The powned this with ussronn?
#
# Second Senanorly,
# Let, you know my not that noble the pere consurt
# Aspeegndess bant moke for, the
# was triuste
# The uthirng their ananot.
#
# Second Sina
# Iter 5500, smooth_loss=44.8520
# Never, and prown
# HFile; You kirdia uppil
# Whise, cold, and tmee than thes nedy the knees, bure gen' my
# Thas the; and, muth noble dortake the reporthrow
# Is ultions at common my dy pulflild
# -s if noble;
# Iter 5600, smooth_loss=44.3993
# unblons; fear Mofe! whow shall
# ghseneatem to are streart
# And sstant seld theer to nerser's not be show
# Which sawe
# How sake forgits, the unberself not vereitredess as your never-lids on.
#
# CORIOLANUS:
# Y
# Iter 5700, smooth_loss=44.0162
# an silicerroan tern;
# More he reate 'Tis courte to hands not godsion; but mets me
# Whose has roddenmand: Our further: so miss,
# Will no mostrean for on, me to dumy. Yet foald
# That had momet an straven;
# W
# Iter 5800, smooth_loss=43.4908
#  the ciswors! Be an like the
# grud his pooe
# Minialy with
# A notefuridn abme a gide chir:
# pettrince his no afrime dince argossing. Bown Corioly swe,, he pidy, to me distself
# But yot: all in o his the sho
# Iter 5900, smooth_loss=42.6383
# ectes the merture componst hanks, wether comtreads, shall the mars'd Mirth agains af
# Him filess! A censhing All sown and tribe:
# This gods, help, thanking unpare all plife,
# elicves
# Mark Marcius,
# Welcom
# Iter 6000, smooth_loss=42.1429
#  soing, your laty
# Freat him in his last,
# Welcores; wool home with unnot will not smore
# Jod; sir,
# Which haliuns you sail, to chough heil;
# For hy nature 'thime,
# Wher homen read when be halk,
# The selives
# Iter 6100, smooth_loss=41.8949
# inge,, know's thou more, at of the mesplest
# With no lies awain tell tritie!
#
# CORIOLANUS:
# Graivor it!
#
# CORIOLANUS:
# Are the Voblces bands boce's! theagh, your gaved, bark's!
#
# First Coth,
# To charge than
# Iter 6200, smooth_loss=44.6702
# us!
# I sanaburivius.
# 'Hown which but where as masthar'd nobles.
# Howher the thive thought offerir,
# O frink words.
# ITtunterly
# That moshour and mistrieds kithers;
# And Marcius owr to. Helcome.
# Which should
# Iter 6300, smooth_loss=46.2521
# ICCapenTGr;
# He bakes if Ot a wren To pedceatmy nrears,
# Shall did is. Givering his befriesd,
# Cnem for my say wit me frome
# Thie our grven un all'd vount:
# I all do speak's that Greess Cope as I am though
# Iter 6400, smooth_loss=44.2958
# theo ay your sexply,
# Are me dount owe plain's wirring will plooss do
# Hisd have shong that  'x musfecan.
#
# GLOUCESTER:
# Bure, wellow as ictreitble 's when do thou dxame the empoal
# Yor me busbrean that th
# Iter 6500, smooth_loss=45.6066
# le stach hands, that de that I houst thou hattrmy that blood'd mersed thence forther,
# Of they arate helfor the hated for time he that had sit leness.
# And then mubped Can in the ward thy hard, bry,'st,
# Iter 6600, smooth_loss=44.5413
# nyll'd up nobles
# Farthilys made this noble leffrerce,
# Brumally i, which know's weartt that that ouanes menger.
#
# BRAKENo:
# No hold in, man this beefil and thou dreeven,
# I'ver by Awhis;
# Which are mAge ou
# Iter 6700, smooth_loss=41.1462
# er; it suchosless senderal? Oay all thal
# Atay thearted timrusel dieldsiess,
# Towirll breant of a kimple of a clance;
# O, not enderter an hereful;
# and graint titakersoust fathes
# The will and the wither p
# Iter 6800, smooth_loss=40.8535
# ll sead, and nove
# Lest by tty curse wyep as heart  of cursan,
# Like say to they loves deathed on it shird,
# on my lert, wefore, chaughter swetsed Nor broun my singed wsechers,
# Which sapeped undent.
# Mut
# Iter 6900, smooth_loss=40.1916
# heart doase.
# I hhave now it his livem.
#
# GLOUCESTER:
# Whis kill not
# That wouty Eine, and precaitatons not have oo.
# Bid I all mosinnanerear.
# I will me take wat teally ower 'twas you.
#
# GLOUCESTER:
# But tib
# Iter 7000, smooth_loss=44.4032
# ur corder's you wor!
#
# QUEEN ELIZABETH:
# If I wepen my Dadines muck myself, her quace grevers cerfors.
#
# QUEEN Gincitys of theersafor this gray.
#
# QUEEN EEwHem the bary of thus majestll
# To my lord yraid o
# Iter 7100, smooth_loss=43.1711
# ovy.
# The grople, aden no do bet!
# Beam no deant, you grely where brongred
# Betabd a grother? indy?
# Comron
# Lrake pleseve selve bid A ghd cerather.
#
# QULEN:
# Brecter-Plabe, betiences and De
# Harve be awawe t
# Iter 7200, smooth_loss=42.4309
# 'd uppresecher,
# To Juc dourann your gnars,
# From that enwer, it did in your have
# Finedand to the ?O
# To, said, I have your were tions to roy upan,
# A wite and Thy event eye;
# Andhe, nor be in, allust it d
# Iter 7300, smooth_loss=41.3999
# ein that, all trest my hed by the eljerl'ddy my soest?
# -LINGMAn:
# What I like-beithel of when prood to the pay thee,-cown cliej
#
# Elent ments dventll'd with theme up.
# If thou hast but, like remeded. Whi
# Iter 7400, smooth_loss=41.7874
# this;
# His rigllish!
# My Cutrike sly bafe
# If this glal and too thy grounds as I son.
#
# QUEEN MARGARET:
# Hably at he,
# Which afay thou trom nigstion!
# If have call bethel as thenrights!
#
# QUEEN MARGARET:
# Edwa
# Iter 7500, smooth_loss=41.1608
# ce.
# Teacherely blagne dash,
# Our harsal,
# What shame them wondigh the repingipe.
# O
# That!
# Peame noce butceld! That well,
# And tell for endon tiuchy fone;
# And tham fair for u cason wifer
# Digh sud?
# Come,
# in
# Iter 7600, smooth_loss=41.1726
# ecce them Curseds, stand, adaid,
# That I little hadnsebt now Done.
#
# QUEEN MERGER:
# Unly even will revenged and share my larts;
# And is deep his Rociused a raysel's Priper. You, giepinghe, my smijfess are
# Iter 7700, smooth_loss=42.8348
#  it belair ofcein motter.
#
# CLARENCE:
# She do y klood, when the wornd in tight stull nntter dower, when to Eesp;
# But it wan we cars on the by deep'd id noble
# The world so.
#
# First Murdrog,
# Methought ends
# Iter 7800, smooth_loss=42.2056
# O prieve my widh to prostion alones.
#
# BRAKENBURY:
# Leastle man evress of you this be deator him; here to our my doft.
#
# BRAKENBURY:
# I wals waster withing how hole.
#
# Fhore and Here, Mares upor that,
# And
# Iter 7900, smooth_loss=39.3695
# at the cuntes,
# Sin my crans ons give at all take
# I Madedese and citbed here.
#
# Second Murderer:
# Eill now a warramold 'twere meldid: meepo, they hid evely flamest it it is that in's but it statt.
#
# First
# Iter 8000, smooth_loss=38.7651
# at you, that
# Shake of men
# To thee no Anvice to like where blooy.
#
# Second Murderer:
# For thame he hath you deator to thou inzersh for is tonam,
# Which his hawent theent to his lord is not dodto withou da
# Iter 8100, smooth_loss=37.4789
# smatelous to we do your soul
# me.
#
# CLARENCE:
# If so vict comminded this,
# He,b for me deee pace to deselvent: thou after now, for sold ands aginating;
# And son by could, for is hell,
# To my now go
# To conma
# Iter 8200, smooth_loss=39.1522
# gh's masemed, it befering go: vick.
#
# QUEEN MursereCLalt.
#
# RIVERS:
# Whop other?
# Rispeccinging murder's nase
# Unto to frings your hall'ful dahal!
#
# KINzET:
# Am, afrorm to kiness Marciled The raytfuce,
# And n
# Iter 8300, smooth_loss=39.7885
# l so resoles
# Said for thee,
# I bouy Gue, to dore conal to be?
# Of your grievous soul love;
#
# BUCKINGHAM:
# Thy roany, To your; knowned vike foraliver.
# THat in thus;
# And I do inqueen nay heaved,
# Who knows b
# Iter 8400, smooth_loss=41.5019
# hce'd, passing.
#
# DORSET:
# To he was with our wy wruck's hit in treack'ss, and heam,
# All to ever blood, knatt'd usteltusiin,
# To thy wrungs' our mreat for slale
# But chas't foou this loth our for Alalo s,
# Iter 8500, smooth_loss=41.3456
#  in the chear hand,
# The hard me, putches, is deed depared a viotered,
# Dhmank?
# evort an storl comforch of him rage
# Cfer my wifeful witreck's not so that I
# Will go looking blaccent have so majestard me
# Iter 8600, smooth_loss=40.9812
# ews mother,
# Unfom my fron my more over bring
# Eve ngred'd indly.
#
# QUEEN ELIZABETH:
# Madam, beeal, your Evwamt'd hortes, of hyor
# The crued, leath 'Twalls harm,
# Than you muty a cural,
# Let him to my hepay
# Iter 8700, smooth_loss=39.9370
# of this forth, his nuty to well.
#
# Second Citizon:
# Gon's kink in our chart'ss of gaoth;
# For Gods will rought stay of so I be mest to the trough on ours,
# My shall: for on my, deais,
# Who this cousin viro
# Iter 8800, smooth_loss=40.2326
# murderost stors stillnress at you.
#
# ROVTOSS:
# Y Gloucester fakes as I heaBly;
#
# yor to knyw-shall be wee
# Trou it he is lutining Groucesterit
# ill the will thouse craoce, my the betwere all.
# Ath shall bot
# Iter 8900, smooth_loss=39.2410
# ou me, but theiseres toly.
#
# MostrCgUCESTERrandicjness.
#
# Sweceed.
# Wold mised beft make me, come, if dusiceal.
#
# QUEEN ELIZABETH:
# And selp, unclewon, sich un would beed swell.
# Makedy fale tell'd old and
# Iter 9000, smooth_loss=39.6823
# ay toldiers!
# Perpet your Cames of ruck LiokolyEd will;
# May  propretine is heles lengaring:
# God give to gean
# Untortioul to her jesding and
# Hurse het we wize oben fils!
# Who say weatint weakerste
# The ine
# Iter 9100, smooth_loss=37.9176
# t.
# The gracies Clasencain Glouccsurae was none.
#
# GLOUCESTER:
# Thy uncle Wimspipt that is did,
# I was this fame of York;
# All se,s I oue this halk'd in a brother,
# I say do't last in the heal, but him
# Toun
# Iter 9200, smooth_loss=36.1190
# ad chost Live ey to bloodours.
#
# GLOUCESTER:
# Though, I he midhing cousin?
# And epbeed you famity.
#
# GLOUCESTER:
# Not, that fard of your grother not Lord.
#
# PRINCE EDHAR,:
# A beor nonghratth
# Thoughtly holing
# Iter 9300, smooth_loss=37.4155
# sion: net talk son; this his;
# And somesly doom retleing plocted they him to
# Lord's Comes met mother.
# How not then, to your mand your hood!
#
# GLOUCESTER:
# A procesble of shally grand?
#
# GLOUCESTER:
# And to
# Iter 9400, smooth_loss=38.1123
# er for his it night, to liighreatey not dusty to vees the make that noeds voas press.
#
# CATESBY:
# Ay, Handing stroake porded
# Tell you nas thou saus forth this nighty and posceusing at were take
# Thereof:
# Iter 9500, smooth_loss=37.7377
# nce as die no, do your lord conting i they all meth it.
#
# HASTINGS:
# God his mincrutt talk make wo, O, have might at your council,, and I live I wound bett priehted are thee,, quieest, truth, and I malk
# Iter 9600, smooth_loss=37.9318
# fe'll.
# Then ciroton, my unquens day prayer's inceace.
# I enerviced royal Cut,
# By make the lood he you distings of whith lives ence:
# Come, cormore her in meem; I, quief your lords, but keinn courness, b
# Iter 9700, smooth_loss=38.4624
# ose 'stramfully conscit, dadnows boy:
# By con I 'om thoure.
# If this farth, witch havlids lives a proot datceds fort
# To-vail offfrtadion.
# If, I may for my lords,
# To-morrow, my lard, when me wingest mine
# Iter 9800, smooth_loss=39.0089
# ktis.
# That for the grace thee are headd tewmuraily see.
#
# BUCKINGHAM:
# Look swreaf the grace,
# Long a drynert an aye thraie, dead.
#
# LOVEL:
# I day! He enemieed
# And grace of the brother head death.
#
# GLOUCES
# Iter 9900, smooth_loss=39.2874
# intends:
# But the past boce with would, the bick your gurly:
# But by, and hasting for michd ho mayerding warken to herefuls
# The criw, time thee hell spick of there--
# Of, the cellum aciongroch.
# It, in ty
# Iter 10000, smooth_loss=40.8800
# en then?
#
# BUCKINGHAM:
# My lord, with his entter you.
# Now, bad seeb'd of liate;
# Untie the mistour of Ebward apso!
#
# BUTKI:
# Now, who' such yight, in equents,
# He wasciuse,
# Encourdem my feir france was your
# Iter 10100, smooth_loss=39.6206
# ignt,,
# We-to-delive your world, himself say and to them Hayres:
# how swork with nom.
#
# BUCKINGHAM:
# I done: pontens of thus madland;
# With hast it my lord; the mayor to pomelence withoredimeth up thouged
# Iter 10200, smooth_loss=39.7224
# His in a done.
#
# BUCKINGHAM:
# I prince: so dismontle to that, your enaul, us Ale is hermoce:
# The  oble lordshist Hand me;
# Now, and thot sumplatitiaging mantarels sock
# I lescuert, my light we end fallens
# Iter 10300, smooth_loss=41.3408
# rs if it.
#
# TELIZ:
# Which dost unto thut by heart not by this happy
# As Chtwemes to haply see, to Dather's side to heartitoo
# As blood to liven to bult it reaponesss as dance:
# Marry so mother'd of instine
# Iter 10400, smooth_loss=38.2873
# olst more no your nom,
# But is igloft you I swear your buthall.
#
# BUCKINGHAM:
# Her, and you ristroat eof.
# But you grace where such refrothe.
#
# GLOUCESTER:
# Cannot I can not my grorarn accipness
# voul our sw
# Iter 10500, smooth_loss=38.1198
# s hit last hunce them.
# Deant my loes me not chied thou death anm that of this the capquends!
# I'll to at all wing the hid lace sies amspecting thereof
# Murged to chmes! O, hall behold tise, where here t
# Iter 10600, smooth_loss=41.2020
#
# For you this kares from thas well meab and plove,
# And city within sLany Lady'd onear,
# Dispested devise your dunberiy handly bitle
# Feor raty of is sufher;
# Fairing betaming for murder by swaral
# And sid
# Iter 10700, smooth_loss=39.9356
#  and I will, the go diem.
#
# KING RICHAMD RICHARD III:
# O bastome one hear ners!
# Dhy quileder Richard!
# And mone you quofesimenon, to tough Edwar, plessseygers wind oubtsWitlance
# Dly since me be me with c
# Iter 10800, smooth_loss=36.9453
# m,
# Ay, be that my mont-would it: she we seeem them,
# Broad the dage with eng at Here, Have to my look.
#
# TYRREL:
# ELany, which the euid is done, Or ears in Pyoking,
# What shall be pnod, and we heemises of
# Iter 10900, smooth_loss=38.9995
# cone thy berid;
# Dighton kone see but what evee no good me sonce!
#
# YAREL:
# Why, you, gent light Remade and me.
#
# KING RICAAIEI:
# Tyour, are generated but the newirg of tinded Happint you are hants  all ha
# Iter 11000, smooth_loss=41.8279
# wagenet us dot wirles and resolty mise.
# Madard was a grave's love cansucion: one hath right,
# His eerer med sible such all denow holy wiod a shower after 'aspent;
# When I am sucd with a dien a bablestsb
# Iter 11100, smooth_loss=42.3555
# ogd prom sout,
# The cruwe carngures shall'd nou worrues of deams;
# Your good theese fither' s bound thee is daughbence.
#
# QUEEN MARGARET:
# Will him ho of's mons youns lefe; of hearthed;
# Os be ghes, why, T
# Iter 11200, smooth_loss=39.4160
# am with might, a death of dragn;
# Forerein bloth, sons aent that in ploperelismen not of herild's die;
# From the brothers a crown to so suppering thee mother.
# I hour next them blodle didst and me when t
# Iter 11300, smooth_loss=37.9526
# very to one with thou to pligen bit:
# the buttert:
# Thy call'd gea thy your shoPy then thy calengiaal, and hell killy.
#
# DUCHESS OF YORK:
# Hear me i, they pard thy other to burthy det oot
# The griver diste
# Iter 11400, smooth_loss=36.8290
# ark not weep me and.
#
# KING RICHARD III:
# If not I make you such and poor veinted wails of adiaus,
# Than all alaies in the poor York,
# Up the mean.
#
# KING RICHARD III:
# Here parros, unsices were agains of f
# Iter 11500, smooth_loss=35.3023
# To this unclind time
# Arout that all a chadint were sinst thee?
#
# KING RICHARD III:
# So her I, and unterple a, he seil- other sweeting
# My ease that of so fad joys let dey daughter.
#
# KING RICHARD III:
# O,
# Iter 11600, smooth_loss=35.8086
# her loush, with childr'n as flest?
#
# KING RICHARD III:
# Say, dether pation my many; and her boch death.
#
# KING RICHARD III:
# Madand woly she her she lave have conques!
# Lordd she, if you whempet this will
# Iter 11700, smooth_loss=34.3121
# so.
#
# QUEEN ELIZABETH:
# Harsh my caulis'll I done.
#
# QUEEN ELIZABETH:
# I will beoad breame thoo.
#
# KING RICHARD III:
# The will anfore's name of thy mighty of more hath bed;
# To be neeizen to mean by more,
# Th
# Iter 11800, smooth_loss=36.6857
# IF:
# Un mayor-by not bred made beory;
# Breath, you hraphe and mistla!ing thun.
#
# QUEEN ELIZABETH:
# Richard, leadht Harth!
#
# KING RICHARD III:
# Where I myselffall bate strecgedimy.
#
# KING RITH:
# But live dely
# Iter 11900, smooth_loss=35.6830
# NEATER:
# The heartingmy good Cotizens are sovereign;
# But then good mother thy norle.
#
# KING RICHARD III:
# I mean, majesty now.
#
# KING ROCHARD III:
# You grace meing mughty break.
#
# STANLEY:
# Sty, norghty good
# Iter 12000, smooth_loss=39.6553
# less Of till on:
# Thus boands Englen, unto two stape, the wong RechEdBunks;
# Or MistroctmI, Ond Messenge, march'd will broke.
#
# KING RICHIRD HIRG:
# My liege,, Yetbmy see:
# I prien now tell: there is kneas
# Iter 12100, smooth_loss=42.2894
#  in thas that was fit wish'd de shome,
# This is frine of England's Ladchersouss, or shall ash
# Should's sweack: 'naven ess bloody.
#
# Chroke
# That Buckingham shall prophe, and and Clarence, and
# Lonour up m
# Iter 12200, smooth_loss=40.8846
# , adven with more no, my rove in Yooks
# If this in take I Iald such still it sa's in take.
#
# KING RICHARD III:
# Up and gontly, Herm's Lord, you, good In bloody
# Ricful cold-night for it.
#
# There I I have s
# Iter 12300, smooth_loss=40.0821
# gin live of his cock of sight
# Leeven, as, thee these times shouth? whe sereling-forts, thine?s
# Sould and reless  ast Buckindsh'd,- of Nellow will ditcle seless:
# Where is mney, or coveinildy,--for 'tis
# Iter 12400, smooth_loss=40.9293
# f You hose that love! my contrius, and yet, in All:
# Good, them army, they hated troubld littinfoll!
# Look on fill, under regree
# And all that I told to flium hat I had a great riel neys on there
# If his
# Iter 12500, smooth_loss=40.1986
# hild. O, here is and God'ss toat,
# Dy shall preatine should arbs burders in dry tratcain,
# Of, if your causes' srrie in athicd have mornaw,
# If you didst conscience and reed sleep;
# If is he im'd the pill
# Iter 12600, smooth_loss=38.4472
# ws in to seen they come.
#
# KING RICHARD III:
# S aiseth of a tormen, my luke; feiest.
#
# CATESBY:
# If id I device, and oin is be that , id our richies forders,
# To-day! my lord. My lord; 'Tis the man themuri
# Iter 12700, smooth_loss=40.4013
# h pause to tongured
# Onnes, agh thou mosh,
# Wed their agood Good good stand we gentle Starmmage;
# Son Roman.,
# Ever woucde I have thy smowell and as haved;
# Would, let his sod, divided If rapers for better
# Iter 12800, smooth_loss=42.1142
# olt!
# With here hime moyer, houriff I have with dush to ank
# That nows of it my aids afends and all,
# Stated all duts to cheer'd in allice tale betrios;
# And is I trum-st here still of your clomish and'st
# Iter 12900, smooth_loss=40.5374
# for whan to hid munt.
#
# KING RICHARD II:
# Sead my mopen  Clusbely dispeesous he lighth!
# Fool, my god umin cowark,
# By be too good, chill to- aware the earth:
# Which blood,
# And by thus shall shall bid brin
# Iter 13000, smooth_loss=40.3106
# ear I drough's soul kinddeed fals eawh Mowbray.
# Once tongue that subjecm'd but it bose
# Make subject's nam, and fair good King this; mush bullow's with this speed.
#
# KING RICHARD II:
# Which norfolk, and
# Iter 13100, smooth_loss=41.5922
# esemet one,
# Encaring much take upul, all myself aftreath moon?
# Me not Upwell'd and lived that here from mirett both,
# Offender's thy lane's soves up thatts of thy fair lord,
# Death,
# Seen me of yier foul
# Iter 13200, smooth_loss=41.4396
# , defore at loves of all:---
#
# AUGARE:
# But he doth, desunt of all.
# Lorch, and laim of misosts sole alas?
# The ears of all: out of resemble.
# Look and whenisher, say, Old God, from ot eps,
# And I repart I
# Iter 13300, smooth_loss=36.9961
# THall!
#
# Lord Marshal:
# Os weavy ome satied To play and the fear is king's areford?
#
# A CasATBT:
#
# Lord Marshal:
# Marshal, of outh his rescenplemend and will ast
# To a body do be kishanisher,
# Why we prove o
# Iter 13400, smooth_loss=36.6251
# Lord Hernd,
# Wast to cale hate course,
# And to ast to justisame the fantt; And and hamply himque.
#
# Lord Marshal:
# Dargabrund his away, and tofend I severral:
# 'trow the capping to sour other? and to he hi
# Iter 13500, smooth_loss=40.1872
# in, lair to do;
# A courn'd and there attenpson nupbeels up I cans.
# Bonatt not buck for we the fangaless but to pain tou last
# Ours: be foun like title too their nawhat toment
# Go have not shall roth touc
# Iter 13600, smooth_loss=39.3103
# igh o' years way despect
# But in my legbing and landon to that will served of conming back
# Is purn a time long with spert
# An I had wints mooth by tgrinks nighbroking with breeds,
# That in nighter winter
# Iter 13700, smooth_loss=38.9219
#  him,
# But thy zook that to think thy bnders is thou cannaxions
# Cousin, justity,
# And never what world I be soil thereity.
#
# HENRY BOLINGBROKE:
# Eveins that a pails to prove!
# Makes to free a turn'st gave
# Iter 13800, smooth_loss=39.6712
# ury, and doubt!
#
# KING RICHARD II:
# To, cree, to me old seite.
#
# HENRY BOLz:
# He duke his hand viition far,
# On piose of his facester'd's love' did-
# He his hangs?
# Whet it, had a juck'd of couctnts
# Of that
# Iter 13900, smooth_loss=41.0128
# of have endmen are breathen for thee tafe
# Nor supjin comes offish shall passet andre lafts
# end in the seed the give imman subserit
# And shall bar of the sans tid are sumpess with smild and lish'd in wi
# Iter 14000, smooth_loss=42.3143
# atiand expraugething thein wengs a tunour hand:
# My chapled hane throag that hath now at ating last oath mean:
# A dear seat my compost counsmily' the houser welt.
#
# JOHN OF GAUNT:
# Wher resume, what one m
# Iter 14100, smooth_loss=40.1682
# er faste is thy loyd,
# Why blood eeglate.
#
# KING RICHARD II:
# I depariding wasted fiern.
#
# JOHN OF GAUNT:
# Nown thou consive thou leaven youse af eid,
# Coffillcast is state of that I would not.
# That all ban
# Iter 14200, smooth_loss=39.3085
# OF YORK:
# His sid they wirtabe did
# Gheir with my begging of had speldegt ade Edward die done.
# Audere friends what noble shame of when thou for the ruve.
# A son, when. No, lion saor CagEiN wither'd,
# Whic
# Iter 14300, smooth_loss=39.3152
# ost infeeding of not,
# Likeland stript this sole wit our cause wouldse?
# 'Thoreiy with thom him; of you would, in my wife
# Like  oway and shake charge, compt not must be path that I no for moust
# Which re
# Iter 14400, smooth_loss=41.0523
# perngsch;
# I speak then supfort, Hereford personessitets gauring,
# RISROPS:
# There be pity these for thus: Thee Irief but farman, broke mare of but From Elfulhid,
# Let be speaking Irate to so rowar,
# The
# Iter 14500, smooth_loss=40.1502
# sh'd hastes we peederee let me nit thouse,
# What hope hose the elue with for on.
#
# QUEEN:
# Then thever not shoppers wander's right his Ladsaf, is ship hope-hand's see that, said's bockly
# What then was sh
# Iter 14600, smooth_loss=39.5173
# essent come it; and wyer oof comes him.
#
# DUKE:
# Whyer altery so!ry from all thet, my will?
#
# DUKE OF YORK:
# Sing, and vare, Coltury comes so on the world!
# what, the cher for there had troubly grought to
#
# Iter 14700, smooth_loss=40.1235
# o too Irelands?
# We will flait, new-reans of wars again.
# This grievenury back wild thousom go jotblingch eye untrue:
# Comfort theo, amsibuienice not Baness.
#
# NORTHUMBE:
# I was? fad endrey, norfagtrancage
# Iter 14800, smooth_loss=37.1057
# aits
# And hanlidy, Rereals of HirselM:
# Herelove and happy rays ttiem;
# And the Duke on my nobless here:
# Broken wied this beBuiness of York.
# HENRY WELLOUFHENRY:
# We are throught far of PErce, it beguily,
# Iter 14900, smooth_loss=37.2603
# y and wars, I way, man, on, before you grave;
# And preceiftion of my son of come, noble know,
# Brove live and thro now the russdos upMince;
# Distions why comes is--him;
# Why, can on why, are proase; I who
# Iter 15000, smooth_loss=37.7642
#  to tows
# In receaven you dismade prisge to utI:
# But welfor will atcante unspoult degering beeL and 'tis pause.
#
# DUKE OF YORK:
# The swrong, if mesten, I cannot my gracis, and leces are fiend.
#
# NORTHUMBE
# Iter 15100, smooth_loss=39.0718
#  to woo, I am goubour,
# With Wit us you king,
# Woon you hishand I cannot go wrongs.
# Cothounese-terpin my head as in levile of death.
#
# BUSHY:
# Sight, threst old too much a caoes,
# I too have here comples,
#
# Iter 15200, smooth_loss=40.2538
# pour;
# Auter not palwed thou foul thet in the trichrol'aged,
# And fined of love things and lork,
# Crest; and dreadye to men.
#
# NORTHUMBERLANLE:
# The lobing of the fiedds the fout,
# Ard letter in the koulds
# Iter 15300, smooth_loss=40.2373
# lich were fireh to-days though blot of s?
#
# EARL OF AUMERLE:
# Hear none his king thy art untreamen; Ang,
# For anoots of my kind; while deliver igo my friends,
# For eight I know recieish of the as Preseste
# Iter 15400, smooth_loss=39.4640
# ed, mestand of canced,
# Eading and man indoute ragen, and of depay soul.
#
# GREEN:
# Where is it read?
# Ay, the Exerm'ds the tirslay,
# And cold made have foo for hands and, the hands of duty?
#
# DUKE SFee demp
# Iter 15500, smooth_loss=39.8558
# s wail and powine:
# By your cour, and hourn sed with them here?
#
# KING RICHARD II:
# AltaRistable Burmonam.
# That impart appast in pheds and Bring your soul.
# My lards, and hea with your noble;
# Tweep the ac
# Iter 15600, smooth_loss=37.6664
#  shall anotheriegh on sweet and ride;
# With's hands you say?
# Let me hole. wouth a power, from Romost and
# Scannot be, now, featon'd I armands.
#
# DUKE OF YORK:
# Them from his him a care will.
# Sheep, who,
# Iter 15700, smooth_loss=39.0875
# g's Earl of stoops, forget bese to Elizebory of have at him mend!
# Conting dischips of rage-beroud?
# Uppersonibarland canst he comes yoursefmer: my corcenter.
# Behold have be from my hend no their peace,
# Iter 15800, smooth_loss=38.7826
# ff may gove
# With to preadtase them shallife should reduit,
# The traiticance the kins from our king? for the firies of the king.
# For nod that long meet alaccold hoo, and myself;
# Drend should me as give
# Iter 15900, smooth_loss=36.7690
# t teme ky she way, retuctom?
# In to the castle oy knight with yo!.
#
# KING RICHARD II:
# The carl to them thee say,
# Will look.
# KING RICHARD II:
# Earre clown
# To be boge, With all your welcond, than Busing a
# Iter 16000, smooth_loss=40.4246
# ouldsed; the dame not the Part I'll tpurbers and BUsorn,
# That he bad may awarding'd,
# The foulst is Swail at desired
# Guilds wellswed at at ees why hand suck:
# What I'll remembers
# Cousin, nighting aporro
# Iter 16100, smooth_loss=39.8314
#
# Thine evers for please. Suerfold? that my beserve so!
#
# GAREENEE:
# Now, seet lanok uminith them that Herrow; pot and friend
# Harth then he refenting my severy, in you:
# For grow pring,
# But sorrow of the
# Iter 16200, smooth_loss=38.1639
#
# And no breath for in just in their had revount,
# Or are it cousin, on know ruse prois,
# And stall I knows so friends and not not on, thou dwerdon,
# That not the trice of the faither here if madam'.
# Shou
# Iter 16300, smooth_loss=37.9989
# f repeel
# Of Clir cousin as foeagands:
# And give enemies hath offereage court counts
# Against this uplagueage gird as die?
# Shortender shall thinkes, our heavy do to his quiat.
#
# LERDERLE:
# Norood cross tho
# Iter 16400, smooth_loss=39.1919
# , were other roy Lords
# Af, though'd it, your dotuney, unyor to my lord
# Wor lordsly titlion of trial.
#
# DUKE OF DURERLO:
# Well to comment be shouldss with or coldwant your dithand, is truask'.
# , your-sha
# Iter 16500, smooth_loss=38.6955
# ken to majesty or heavy did,
# Is Ivence shato may I hithey Iredial to line!
# May limgets dayought pluced titldion. Marcy, for, are?
# I have thy king a did time,
# We't with all prop are that off majesty no
# Iter 16600, smooth_loss=37.4989
# h thou livants; Diver I log,
# That he mear yet bit many's stop with helping: here the enought,
# Whilst so I do not nor thine Lord for of tremsish.
#
# NORWHUMTERLE:
# My sorroo, here, if I can so veiglans.
#
#
# Iter 16700, smooth_loss=37.0381
# inks it, in bund tell all eye comes?
# My frown, and I stand flemy bloody sorrow,
# Yorr name no turn, Gentle bid:
# But oo comfort,
# What she this flittering it was breathnorat
# Come is Howry,
# Stay if I will
# Iter 16800, smooth_loss=39.3457
# om folloury nothag again greatly thou wilst up,
# And my facet? hom Norrligilg To Wail;
# The sother tit oth my little see,
# As I send for thy depting losne ssome of the soul
# Amon; is, my Brinter of falst
#
# Iter 16900, smooth_loss=38.4933
# chard.
# Go fear think me our pay look this into than say 't.
#
# KIDG RICHARD II:
# Vord; with the heart me.
#
# NORTHUMBERLAND:
# Then iff and to way to dead, I mould the rest.
# St qoive me like gongen apparany,
# Iter 17000, smooth_loss=37.5994
#  Aumerle the eget to have depalst
# With treignble truke that beacted are like off!'
# Anothant, on breath perpite. Lode him elood and know, I knowless on mine?
#
# DUKE OF YORK:
# Garden pare beage,
# In with h
# Iter 17100, smooth_loss=35.0354
# ng,
# And must yet intreak?
# Have hend! my Rocaed time wilt there.
#
# DUCHESS OF YORK:
# F with a troot sunder son.
#
# DUCHESSOOF AUMERLE:
# I like gods betwulsed: they do be!
#
# DUCHESS OF YORK:
# That I shall her
# Iter 17200, smooth_loss=34.4043
# ot ly Lord some lords, that even with a way
# Suncender may my enemymanes of canem.
#
# HENRY BOLINGBROKE:
# In the way be stringeed beanten tale thy son,
# That I sake the king my majesty love to my sate;
#
# DU
# Iter 17300, smooth_loss=36.3007
# eftnernounds the heart'd me these
# Without whathers are
# Scondrest matter undirged,
# Thou thou forgabrout dystand forgnts
# And thou shen porton it looker painsK
# Take his dost this for his profaneed to may
# Iter 17400, smooth_loss=36.6813
# od do not sick and word shall prove kneel, how ma kneel'smegg my wan.
#
# HENRY BOLINGBROKE:
# East; or inteverserfait,
# And to my cousin wordt wich word and will it is heart.
#
# HENRY BOLINGBROKE:
# Whe'crest,
# Iter 17500, smooth_loss=39.3133
# ewer tiels on these find myne other be:
# When timan! us,
# Ahe!' ain than what come to more
# The king for weak it an any mess bedge,
# Therefore happinians  imonoughts at tear
# My did makes of myself cryswar
# Iter 17600, smooth_loss=39.4654
#  state cletcence
# Tale hate no earth
# My horse: hath is and o'er jecu;,
#
# DUCHESS OF YORK:
# Alas: He discenting with in the king'd To king,
# Bade is bear his concennoting:
# Small he: lemply all.
#
# KING RICHA
# Iter 17700, smooth_loss=38.3934
# ts of this dumle, I thy king, his viunt, here;
# For this penume do orted is out
# How dither to I Love:
# His o pardon him fire.
#
# HENRY BOLINGBROKE:
# Kin -upI his peor sim thou to
# From blood, hatch sumes Ev
# Iter 17800, smooth_loss=38.3742
# ury.
#
# SAMPSON:
#  to thou will behented now I make to mave me they a?
#
# GREGORY:
# 'Had them! as what shall bear them morsul it;
# Buin tpuve king thy blood is land all acled dull is in thee,
# A'sin the galfa
# Iter 17900, smooth_loss=41.4662
# e's anlemmedes.
# Thize it your acur tabge aboth He'st to come on my stage,
# To ,isourtious tauke it vain cause o'erturb that move.
#
# HENTYLE:
# You herein tawe's tears?
# The earth here chall the quarrel of
# Iter 18000, smooth_loss=41.2773
# I would will grare, here mays
# go are cut les herb?
# O, you sague, as to or or deerings,
# And day whence, thou torness ne,s,
# 'Toll helcome come,
# And come,
# And fortunnet occupous say talk out from sake of
# Iter 18100, smooth_loss=41.8890
# er, that cut here;
# And stepast I they art her taughing as lag.
#
# MONTAGUE:
# is tyou and hath the knees, she wid Henre! shill read joun leave in sigh
# To prace?
#
# ROMEO:
# AFay? You horse, where chappinery,
# Iter 18200, smooth_loss=42.1978
# as woeld,
# To swown heaving truen scaunt, like ouch monds more,
# Stay such no croods sine senight,
# Fire her content this liss nemit all prest
# Makes the think, welcome, who theres, harch! But there hin s
# Iter 18300, smooth_loss=42.9022
# nemies feeld.
#
# ROMEO:
# Net teact, Lovy Here; my uncle Toudd I not many consuntence that fooser?
#
# ROMEO:
# Inder there?
#
# Servant:
# Goot fair choclosaters; furtairent; ove write yey Rhmold antellior tomment
# Iter 18400, smooth_loss=42.7295
# y old forbe! down! up this now:
# And my other wa! wryther come on thy in the shame.
#
# LADY
# CUCET:
# About. I'll do had
# hear our own:
# The hooke-to and,
# How frush and God shinle With my thou age,
# And judgai
# Iter 18500, smooth_loss=40.6455
# iers is unter to humder,,
# Right in hiers that marrow: when eyes your fiems in the cells:
# Whom clike? his sun mady adhing aher beconsed Yeagh
# to bear when of ner;
# 'Amolst, luke in now his match:
# That y
# Iter 18600, smooth_loss=40.9197
# ve be me do I; terch from thou draClage.
#
# BENVOLIO:
# To love the laid in soul!
#
# ROMEO:
# You shall th uster, and quint? o.
#
# MERCUTIO:
# Sounds and  here with me, you are !.
#
# BUNIET:
# And say the loens, Come
# Iter 18700, smooth_loss=42.7882
#  making being guts he feok of
# One, brain'd she abrive!
#
# ROMEO:
# The forcence, of I amned,
# Ungeeth rube, which of longs, and slive dreams them nothen clorps;
# That shumblish of a sleagp, time,
# And man, a
# Iter 18800, smooth_loss=42.6825
# r due.
#
# Amus:
# Portage, aft quend take his sis!
#
# ROMEO:
# Well, this sprag-helconcome; ask.
# This is Rameo's long wife a bear,
# Will durming's remoce,
# forsence courtiorous grace;
# He shall of me so she
# take
# Iter 18900, smooth_loss=41.7181
# oszests mind Murieg shanos glarting by this him.
#
# CAPULET:
# Pyly stants shows him! 'tis not content perfor' lengs;
# She sit sesil myve trow sother him to a some.
# Go, maints Joln, is sit,, to Friemap't:
#
# Iter 19000, smooth_loss=40.3465
# do west less at our smeetly
# Turgence bledish desace.
#
# ROMEO:
# Overold muchy strest.
# ; munt fear at he bed feethes wholy must
# Hes rough forfect, that comericw of the demps,
# Turn it fulst to seend learn
# Iter 19100, smooth_loss=41.4249
# o some fearful, earth! But bliflet is:
# Her leavess never thees dalls;
# Be young is time weak, her that were too seek,
# Antont too ear, Our sine of boed,
# She wade enonged ier: then, of conjures!
# That she
# Iter 19200, smooth_loss=38.6702
# eet thesenfed thee die.
# Ain she is never! him a cannot do,
# More thouth thee,
# And is I loigh they and my linether light two fairing from the besids
# Of thees largetels one for tward lag,
# That no thou ca
# Iter 19300, smooth_loss=39.0038
# d of my bright,
# To be will telr me condert ise blunation, frow too likely dide
# I nebt that light swear's terat, stays any falle: ant enemy.
#
# ROMEO:
#
# JULIET:
# Whantish sweet Montague
# Was 'tsect comes no
# Iter 19400, smooth_loss=37.4546
# arjine's hand.
#
# JULIET:
# I mean nciese they somwould tweftere,
# Who love a moesell gentle back agaand, gentleman; nege
# I tortwaring horstern stand no gean,
# Is that happy wherefore show hath he thee this
# Iter 19500, smooth_loss=40.5946
# erion :
#
# JrLUMEET:
# And whereial would health but where there?
# But my holds it engueding his thus is burders, there beaut lies
# By so soon and in the birrow pitythed breath,
# For then dear with merts.
#
# R
# Iter 19600, smooth_loss=38.9410
# ttliin This wand.
#
# MERCUTIO:
# By, Men and I in thy sweech stranglinst.
#
# BENVOLIO:
# What me comain'd by much pall.
#
# ROMEO:
# Not masher sannd night some canche allow;
# Too love holows sweeted to love;
# Of co
# Iter 19700, smooth_loss=42.3936
# then.
#
# MERCUTIO:
# Mery gone! take for marry,
# cellies, smowing.
#
# ROMEO:
# Pito eys woll me.
#
# ROMEO:
# Those; their moered is also my fuintis.
#
# MERCUTIO:
# Marrow; these man proof night?
#
# PoRIS:
# O, sme to cie
# Iter 19800, smooth_loss=39.7158
# :
# I which are hest concoy is
# to have.
#
# ROMEO:
# A ainge eite of seccout.
#
# Nurse:
# I pell with now it is; say yay bittoto did made young in my time!
# God you are and yet I'll never coze.
#
# MERCUTIO:
# Gely an
# Iter 19900, smooth_loss=39.8199
#
# me locy,
# Shalk me to in ure
# hiar to did, monly will not dem,
# shall art more; if you thou boted than, you be:
# I passial; it two thy feath.
# The beacuronous of ming tell ment.
#
# ROMEO:
# A pary
# the firssli
# Iter 20000, smooth_loss=41.1506
#  no loke dead
# Lord,
# Whoch, see any asy eletter;
# O heave willby, then, I say 'Paas  he say weack as with badd, lark,
# misalied; sir;
# which  agot not stay unbould, with anO the spea, and why man! He is f
# Iter 20100, smooth_loss=39.3064
# s to they other.
#
# JULIET:
# Host lady swreting a child to-Ghour in that I'll breath,
# Where dot the othergiesy bunnsting dows?
#
# Nurse:
# I say turn yout is the noble;
# Says in not caduinger lick. Hither's l
# Iter 20200, smooth_loss=39.8359
# loop him; word, the soorrow, when is one in both
# now that say they wirrind lavy icf and no meet sire
# :reads,
# in thou art happinornes on atater and any sadsemant he ne'er.
#
# FRIAR LAURENCE:
# Though stays
# Iter 20300, smooth_loss=39.3430
# ones: thereffring,--No claot sugh
# Twill that with a ford!
#
# BENVOLIO:
# Iuther?: and reshvelting
# Vees' sweeter gentlemEn, give shiss, or,
# with I belough of covered thou knave
# Tilk word, I! hear twey, Rom
# Iter 20400, smooth_loss=39.4118
# ee bragg tobenety sabe thou have thus' lide a retchubing hand,
# In the hust unsuchit beat ma patiof arminpine
# Shall fortune dreat vamilen'd I
# do; by an aoth me givemen!
# Thene usce-day tome me to demeas
# Iter 20500, smooth_loss=39.1519
# t Reslalt;
# And, go to You hold slew with him? Rimeo it, hum: and nain thee but ann
# Ay, lipe Benvolio, Loue sliefes! Where the vill go true villain,
# And extuae thy life follow and who to thy musio' qua
# Iter 20600, smooth_loss=39.7738
# ave sometimes;
# And, catch night very tententy, be-my you the unhunds:
# ...
# God let is fowf:
# Bring my
# Godmost with offends of Edward foul is fried
# Iter 503200, smooth_loss=42.2926
# gud.
# That and train foe me deeved, tendertry.
#
# RICHIMaTH Chreathinge,
# He shall shard dishopost me in Poile the mean frief myself?
#
# Chridgment prator'd in the dowst I leave made in Ruchds in my severru
# Iter 503300, smooth_loss=40.4296
# off of acquifto Say. Thene; foul there voice and what surfised to-morrows
# Your those so but them.
# To the renvy.
#
# KING RICHARD III:
# Te stand to you will your and tale?
# Rement and what two furl no she s
# Iter 503400, smooth_loss=40.2581
# s look, ever word long of Wale of plant in Will
# If on aving me inment or everly but,
# For tell is wicker up your recuest in
# Dirmss an see by might.
# Surly, welce to be wishmen,
# Sun your within.
#
# HASTING
# Iter 503500, smooth_loss=42.3294
# noun you their both, face
# Abey:
# My botour true here better fain?
# My goethy, our frow'd of they at by you,
# My thou speed reached whost told treachared at;
# Bed's gave upon any thou young old our fetivin
# Iter 503600, smooth_loss=42.3214
# MONE:
# I am 'an day, high my housan sinch, givl I swalt I am BapH I stouth:
# I in make on than count, why,
# Argjosty,
# Pauch, my well.
# But, how I doublish'd allous on us blood of and as beyarbass bid impo
# Iter 503700, smooth_loss=42.0810
#  grace by this is'ct.
# Did, say peards, somty ed you day his friends charge:
# The dead God my dunisghous
# Flaughter no.
#
# LOND Forth a remen
# Inmia
# Thought for to descher to my loed
# Inthalt I day suistly B
# Iter 503800, smooth_loss=42.0246
# est desot be be full doart
# On the swept of injor;
# Yet, what my anise.
#
# GAUNT:
# Which so be socl's again.'
# But O, for to shall sweet wold's been,
# With deaging fear me so be breators iatch unjult; wate t
# Iter 503900, smooth_loss=42.2115
# .
#
# JOHN Oxeve thou not and as thous name.
# Diff myself:
# He what.
# Jutrew reathors times wrath again livered:
# Must curse, whom courth, my life.
# We I neasue thy worts: inmite idlups.
# Impet life, up treasu
# Iter 504000, smooth_loss=41.1699
# oes,
# Desigefore my fall;
# And instend there ted dest and of his highness
# My here,
# None kneel,
# And mees defend ame and me, myself,
# Engmen Mester vial, it, nome--
# As God mother, Give.
#
# Seconderful doth m
# Iter 504100, smooth_loss=40.7433
# cause abus,
# To my but who need right
# And cauntaims.
#
# JOHNah,
# But he caurtly lain end low and let my spup is and mine;
# From enee in thy but up young love Grey,
# Jof God's ladenious,
# A bloody prosperinhe
# Iter 504200, smooth_loss=40.8411
# e;
# Som! God's country'st
# One niging persureth skee untimes blough to frieft
# With brance on firsh cournervising of found, trumpet
# With from skee.
# With sistisgbrain in than of suit Tumble crows up and i
# Iter 504300, smooth_loss=42.0383
# l--
# Nor livial un.
#
# BLOND MARD I But his soveritin,
# Have put a firshin lan of laist.
# Bath espald me.
# Such ur and katen's This is a from the turs.
# To bath thee--
# Be year, choise land's is verey his pla
# Iter 504400, smooth_loss=40.6511
#  the like hath and wain wrwer my meing;
# Call lip his dishore was and live, shall he eed the wer to my childle to ming; as seen my sween a and never worm:
# And thou will: what we not my landly banish'd
# Iter 504500, smooth_loss=41.0897
# :
# That more of own the uncle,
# Basting the banish's forwer?
#
# JOHN OF GAUNT:
# The both who thou comoind, and thee
# Teney?
# The hand our Chiefasing.
# Of thence both head,
# On both the execungrains togere empt
# Iter 504600, smooth_loss=41.8933
# s, he for nurse.
# For furrel sents, are dixfull six art liberasher royal gravis rash,
# For wretter to anowards is that auth our soveren sejuls, are well, whomble shes, a than to shall,
# Takes iat Great a
# Iter 504700, smooth_loss=43.7974
# se rid of ress from speit,
# Thou manise rustime: when this didst party their the Hartesiclish bittion.
#
# Forses bird; me thought fortunemity liege, that trierfold other
# Myssebrems, the tribured--
# Withor
# Iter 504800, smooth_loss=41.4025
# ee.
# I hath imse.
#
# KING RICHING EDWAS:
# I thou king feast;
# 'el mother their know singes? the live,
# I, its, let! a his the far would oldiedle,
# No, in gentle last, seems, to bound no!
#
# JOHN OF GAUNT:
# All
# Iter 504900, smooth_loss=41.2469
# een years;
# I lord are itserve is is that is if die sincterly as age,
# Now highes dears escorsed sitent out thy son as as home age.
#
# DUKE:
# Like ian else, bird,
# As yield, he, it remain; as asselves my sa
# Iter 505000, smooth_loss=41.7683
# Bot Yet, facey--sueet-first as Gentle behold seeks nightsharust yours you---hasteverfully compase tongue thus way he thoughts he art Geotles a forth
# But stook'd tell--
# Baof of thy Edward's from eyes y
# Iter 505100, smooth_loss=40.8403
# rselvest drean what no bad his noble what hands'd'st noblatest the vicior'
# But what bloody afforder's for abupon'd
# Take be not like. What the warring wart he hath too what a wars and a thank not chate
# Iter 505200, smooth_loss=42.4552
# rains dream, I will women with you devines to that I spealten,
# Is I king; then's majesty seping my brother:
# Blate Hard: suct I king,
# Why do majesty to the doth are,
# Withere barsels counts in land the
# Iter 505300, smooth_loss=42.3628
# Eproned fortshy!
#
# QUEEN:
# O, to gentlest then, short we myself,
# A child to majest achidry, his being-for and their werts how my hastess not trummonesty,
# And fault: Becomes an our Buchasted grouls,
# And
# Iter 505400, smooth_loss=41.6338
# Here no will tell Basces of with notless upon: is postent.
# Is not Is measing, the king no pains they us thee away; Bucking mess our ahine oar my greens:
# Be in this exeverew;
# And me you take my long so
# Iter 505500, smooth_loss=40.6672
# rgar.
#
# NORTEERGHAMY WARY:
# How highnate off, woes levenger'd: we dyorself,
# Whoss these so? not changes way sorrow.
# 'Tis for yourself, Engless thou would losgers of Yeas what heer to their exceat
# Now, w
# Iter 505600, smooth_loss=38.4053
# on other the accorty
# I happing--morwandst make wonds to the kins of myself yousant Calpose
# To-come to take to in and thou art lord that goon the othing if that go rest to Time of
# To say to know is yoa
# Iter 505700, smooth_loss=39.7484
# owley.
# Call, as nume with lested allouse hath of my louds did ledsued all.
# To and stalt:
# And many detrankle.
# Pardould himself pass'd my are, nottal herel he by thysure
# Then all what heell souldering m
# Iter 505800, smooth_loss=40.7732
#
# And sweeth as which with spatest my lordle eds yours
# And fath Soolor Herefort!
#
# ARRY WILLOUCESBY:
# And did me all Richmeoosts stay--
#
# ERCHis Rarsegl'd:
# My sold to the king?
#
# HENRY Richers And right:
# A
# Iter 505900, smooth_loss=40.4880
# art her prefer him in their are to haves and leance the reall I unbough a know my with my lord name yours: your see hasts you high born my offer your a comence away fliots to mess.
#
# DUKE OF YORK:
# Now
# Iter 506000, smooth_loss=41.4371
#
# Scomen:
# To hour no good;
# Left wall pluke offed hear good?
# Go, my gold
# Nor seen off man for our havels rage.
# The queen! Oh the let of powels.
# S hath and father, my chant power foul; and forgere not fl
# Iter 506100, smooth_loss=42.7854
#
# What falstwelvy heavens, by you: then breaks and great and well lady liles farther's thy sjave--formistion bind tow sick
# With higster thy heave acclams
# And calls and villands my angert, your bady
# Gan
# Iter 506200, smooth_loss=42.5667
# ess,
# That of make,
# The nature
# Blaking eart his meany was aumerin for he, command; and are curndshur at sals:
# A makes his with hath ashard can we laid, in foor all of Hariles
# And all some which at head
# Iter 506300, smooth_loss=40.8464
# Rick'd.
# Rachards let's let me;
# The far were.
#
# KING RICHARD II:
# Dear noblers that worn'd, What come, with warder his far
# Re and the devoir,
# A dispatch'd the lears firms.
#
# SINal:
# If ashore:
# Say.
# Straitt
# Iter 506400, smooth_loss=40.5237
# ot heath beher's worth be leagnts luned.
# Mends his rain.
# May doth enchands Ement; and lend peaming delimber company littables and we learness he pridess, breen, him lader.
# And his paper and Baptain ga
# Iter 506500, smooth_loss=41.3486
#  grace,
# His pains by here's and waring worthing our tatter one sicks the kneems, ven cravill tremicester,
# Hem shall appoish Hervishter me,
# And was, gain and screet slit mest we wed, face it give to mi
# Iter 506600, smooth_loss=41.2388
# vio, I law of men your late,
# Wellling their gives, and templessmen mast no it partomice and done,
# Sistam still ond little fair friends?
# Welcome the stay pads all give peachlandal wayill as said the de
# Iter 506700, smooth_loss=39.4244
# o I came to thou man grief it by he flower, not of court ruports?
#
# FILLOUMBERLAND:
# To each the joy.
#
# QUEEN:
# If that the world that toward the war torther it It to jad's spers as I ne'er is joy;
#
# Lord
# Iter 506800, smooth_loss=43.1020
# ents they speaks spit sparing of their standes:
# The with shall poring strister's deserved with disca,
# That as rapsot the sud right breep, om say to desperts cas done,
# And serves, land, last and mants
# Iter 506900, smooth_loss=41.0515
# h
# rustin's son,
# And in a wagers' theateft to they I, king 'tis telf of That care
# Towere has shall wint
# Than smake and more that I have as heurse runne of him that station's a cloud on the tirstetrum's
# Iter 507000, smooth_loss=39.9187
# elf I shall honirald I are fire, the Duke's forl is did away it is for armnest; do vain bancal thou are it heard the dare withour revell lie,
# In with you show brandle lie talks thou wound, and do I am
# Iter 507100, smooth_loss=40.8492
# using been;
# And, see fondy are bace,
# And that no men, by their God's liest?
# And the ease
# Against are shall'd and deputy their will just abroy,
# What shall on father'd iflict the should?
#
# HENRY GROZO, C
# Iter 507200, smooth_loss=41.4316
# ck
# Till dishopestly health coming of crimgate your sent too their emars,
# Where. Cave
# Kind swear, we to see? his boun.
# God doth is now hear,
# Then sir? foow I so?
# Here opporious, to the shalting.
# It cau
# Iter 507300, smooth_loss=40.5642
# :
# My care of heaven away one procaried need and owam
# That it sway a lenge.
#
# NORTHUMBERLAND:
# Poull with more womany,
# My sent thy fond,
# My likerew on with God,
# Die all undeather any with do well reforth
# Iter 507400, smooth_loss=39.2765
# hat have grone,
# This room, thou droamed:
# That shall corns me, myserve here; thou showers a reron:
# Reach the groush or so that he thou shaile.
# Good my last,
# To sparpirs eye soullkficery renom'd:
# The fl
# Iter 507500, smooth_loss=40.7325
# r.
# Upon thousand Richar fair, time of bood my pase and gown to Jeshive my noble dead, to dead shall be not,
# That lord, and king now I aphame here Jomais
# And gon,
# Bushalk no moout mine own
# Too Ry royar
# Iter 507600, smooth_loss=41.1742
# ber would as my prevent tending berad's me! had of my devil, to to my were in that wounder of ubjects my good ever to kneeve you make to house not here feard.
# Mnetful mind; do man's Bolingbroked our r
# Iter 507700, smooth_loss=40.3639
#  this them.
#
# NORTHUMBERLAND:
# And at hither panshipt that;
# And and the toou,
# And present thee! but let there leaves.
# Mouving at over happerred as heaven with theatest pake! he thee! the lamp ofted thou
# Iter 507800, smooth_loss=37.5720
# re it:
# Let with hithom! and me, sorrow idlel rede toou! for mean! I bod! meast, in now, lord! Bolingbray? ' with this lean!
#
# DUCHESS OF YORK:
# That for when queen, do!th. Nor you, who neafit!'
# I carela
# Iter 507900, smooth_loss=38.4147
#
# Spoken, anonownst is sages,
# In though nets not mine an they, thy seen's Bolingbroke, dispert's her,
# Begat,
# I'll pater him here.
#
# SEY:
# Harry,
# Be foundly I am
# Conly man!
# If sorrom see,
# And son.
#
# DUKE O
# Iter 508000, smooth_loss=37.9453
# nch!
#
# HENRY BOLINGBROKE:
# Stan did base his gooddon thrans man
# For, not with gon! Richard's did deach shall back you designed your himself!
#
# HENRY BOLINGBROKE:
# That ne'er's love!
# Sic and bed
# Withort th
# Iter 508100, smooth_loss=39.2623
# rand:'
# Dist hopousours confessant.
#
# DUCHESSS: OF YORK:
# Nor pard tell trutry is through estedly fouse 'twere wed's appe 'tis not words neg near's' now;
# A woop hath a thou goold shall vene without 'mse
# Iter 508200, smooth_loss=39.0753
#  gestercue teatful brother'st,
# ANvest its retught I pitily of not,
# And we uppoself.
#
# MENERY:
# My fetconterly, state to help on stand,
# At, the reoping betterst;
# More foest;
# And would the ere so it the g
# Iter 508300, smooth_loss=41.8251
# er he so
# Thoughts son it it though crue batten every a plage!
#
# JOXThance:
# That is Things it of my to inders no a be against with that no set this proints,
# For though not crown'd Richard
# To clard to fi
# Iter 508400, smooth_loss=41.3826
# rebef Bear?
#
# HENRY BOLINGBROKE:
# Well thee to crred dee than the would now, and whicele the deed heart
# That is his the king's leave her from there tears which I will them rest stile cheek
# Yet the is ke
# Iter 508500, smooth_loss=41.9953
#  sovererests; my woll.
#
# GAOP Som' Nor Sovering:
# So born.
#
# SAMPSON:
# So thou shiright.
#
# CAMRESS OF YORK:
# My Licious of thither is lady beggar. Laion toletil' doom.
#
# GREGORY:
# Go thy brought.
# My lord bloo
# Iter 508600, smooth_loss=41.0385
# aken, 'twself:
# 'The deentlet.
#
# BETHAM: Vle:
# Yet thee then, what water, and bad thou thee thumb, battal: though strack'd the speak:
# The prace!'
# All, the peace!
#
# VINGSAB:
# Part murth at state, other befo
# Iter 508700, smooth_loss=44.1153
# I'll head him, where,
# To both,
# thouts wase at fightery:
# Pombound my word, men's off thee:
# My friend,
# And women where of The worship
# To me of take, I hate I subretter'd with my womand?
#
# SAMPSON:
# Our ou
# Iter 508800, smooth_loss=43.5168
# ed of an its, heart,
# Reglious!
# You shalt see, leave, the father, there it I late, ool hand contentle,
# Make stort thy frienchastal-from that wash thous station.
#
# BENVOLIO:
# No! Stole, by his colsed the
# Iter 508900, smooth_loss=42.8272
# deated up heart to Citizen her daps beauss,
# If he pass beauty that should beauty that whice hate hands fathereis surk me.
#
# ROMEO:
# I'll seem paput beauty leasur,
# But best face.
# The quased enquhirsain t
# Iter 509000, smooth_loss=43.7704
# n mangerly with you artly true bog at sceluil-remedumbod curpic out oberon, sire heate--
# Flow not without puppurpoit----
# Who pupties of,
# Which mado parlary to my are petitely by our thou builgl; but I
# Iter 509100, smooth_loss=44.2779
# Bolingbrar:
# What, my law,
# Uncience, my her, AUMER:
# Were cus anded tumber,
# Whose.
# Werrum which what being thrust, it was caulther allow
# Lookard I leaver', where her?
#
# JULET:
# What now the dervers! fathe
# Iter 509200, smooth_loss=44.1023
# t; the face that me true wretterted thee that death starb I'll Jurnest tell it stant ere 'tward! Marto my trembrays?
#
# GREGIET:
# To treet, gappraitothet happy the ease;
# To I opented thee with it is stee
# Iter 509300, smooth_loss=43.3590
# out his mays the bashing be.
#
# Nusump:
# This erting beheld: mad--forant, prevers a much in me:
# But even the pluck love;
# But of Rancainus!
#
# Nurse:
# Wilt hours, widdle make I lade in tarbun:
# Resptermint:
# T
# Iter 509400, smooth_loss=45.4759
#  a gray at rorback becomenth of orp'st how a hither wratitler than of macors this camean-remamces: follow's trom a complorime-gloomel an me
# Thou call thou worth of my lights spiclack of grief beast of
# Iter 509500, smooth_loss=45.7330
# ing too ne'er mortay!
#
# Second:
# Someterly is that little and a late in an.
#
# PETOP OF SAE:
# Bant, and old too not, and one the pray? while one lord.
#
# Second:
# Of, hold not now, and this ofther, and thesel
# Iter 509600, smooth_loss=43.7789
# this voice, at to tollow and to tamfor thin like dome?
#
# CAPULET:
# An hore forth a and, me side:
# You go at verity teal of if it.
#
# CAPULET:
# Which of that villain 'twarm.
#
# CAPULET:
# You, in, fall'd and, wh
# Iter 509700, smooth_loss=42.6363
# h:
# I ave a too cover be nages inse is a room tother too so?
# I syemet be deschment; to in the tose; an the go;
# And heated tongues a for know gown I dabuse leave holadlard, too.
# I prayers the gentlemen,
# Iter 509800, smooth_loss=44.2958
# ape the presenth this lect her grawied,
# By gentleeclany one! the, for treams I have vexry, she her, not is this queen, hen fair, let is
# Which than he enish anvimbed is her sweet;
# Bey go better the new
# Iter 509900, smooth_loss=41.9868
# o-mysars
# And take cannot not beave
# As the might
# Offlight fall they
# A better curest
# Of go, sold blows, sigh and would
# And, borny an
# O, by topperfor too my dugbble fairen one not trime-beforget till
# Ref

# %%
print(sampleGRU(model,  model.init_hidden(batch_size=1), 1, 400, vocab_size, ix_to_char))
# Out:
# Or rabs I greain,
# You command with rich confesses!
# Out o' the vut what's subjects sorrow scone, upen;
# Hid touth on't you, Tranio, what the crown?
#
# First Citizen:
# For cale of it.
#
# MIRANDA:
# The fertessies we pinch them,
# The midds and humour whose officer as we
# come braguedre more pieced belihven.
# Come umon: thy satisfall fears,
# To wash'd their gaughes change, and women
# And how it perfeivion'd as suf

# %%
char_to_ix
# Out:
# {'i': 0,
#  '\n': 1,
#  'e': 2,
#  'f': 3,
#  't': 4,
#  "'": 5,
#  '-': 6,
#  'M': 7,
#  'Y': 8,
#  'D': 9,
#  'Q': 10,
#  'V': 11,
#  'G': 12,
#  'z': 13,
#  'n': 14,
#  ' ': 15,
#  'v': 16,
#  'u': 17,
#  'W': 18,
#  'p': 19,
#  'S': 20,
#  'O': 21,
#  'a': 22,
#  'C': 23,
#  'w': 24,
#  '3': 25,
#  'U': 26,
#  '$': 27,
#  ';': 28,
#  '.': 29,
#  'h': 30,
#  'I': 31,
#  'T': 32,
#  'X': 33,
#  'q': 34,
#  ':': 35,
#  'd': 36,
#  'L': 37,
#  'A': 38,
#  'N': 39,
#  'g': 40,
#  'P': 41,
#  'r': 42,
#  'x': 43,
#  ',': 44,
#  '&': 45,
#  'K': 46,
#  'Z': 47,
#  'j': 48,
#  'R': 49,
#  'B': 50,
#  'H': 51,
#  'o': 52,
#  'y': 53,
#  'l': 54,
#  '?': 55,
#  'F': 56,
#  's': 57,
#  'm': 58,
#  'b': 59,
#  '!': 60,
#  'k': 61,
#  'c': 62,
#  'J': 63,
#  'E': 64}
