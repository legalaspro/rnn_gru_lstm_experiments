# %%
import numpy as np


# data I/O
data = open('input.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
# Out:
# data has 1115393 characters, 65 unique.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


class CharLSTMOneHot(nn.Module):
    """
    A LSTM that takes one-hot inputs of shape (batch, seq_length, vocab_size).
    No embedding layer is used.
    """
    def __init__(self, vocab_size, hidden_size=512):
        super().__init__()
        self.vocab_size = vocab_size
        self.hidden_size = hidden_size
        
        # LSTM expects input_size = vocab_size (since one-hot dimension)
        # batch_first=True => input shape (batch, seq_length, vocab_size)
        self.lstm = nn.LSTM(input_size=vocab_size, hidden_size=hidden_size,
                            num_layers=2, batch_first=True)
        
        # Map hidden states to vocab-size logits
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, hidden=None, cell=None):
        """
        x: (batch, seq_length, vocab_size) => one-hot vectors
        hidden: (1, batch, hidden_size) initial hidden state
        cell: (1, batch, hidden_size) initial cell state
        returns: (logits, hidden)
          logits shape: (batch, seq_length, vocab_size)
        """
        # Pass x directly to LSTM (no embedding)
        # output => (batch, seq_length, hidden_size)
        # hidden => (2, batch, hidden_size)
        # cell => (2, batch, hidden_size)
        output, (hidden, cell) = self.lstm(x, (hidden, cell))
        
        # Map to vocab logits
        # shape => (batch, seq_length, vocab_size)
        logits = self.fc(output)
        
        return logits, (hidden, cell)
    
    def init_hidden(self, batch_size=1):
        """ Return a fresh hidden state of shape (2, batch_size, hidden_size). """
        return torch.zeros(2, batch_size, self.hidden_size)

# %%
def indices_to_onehot(indices, vocab_size):
    """
    indices: shape (batch, seq_length), dtype long
    returns: float tensor of shape (batch, seq_length, vocab_size)
    """
    # F.one_hot => (batch, seq_length, vocab_size) with dtype=int
    one_hot = F.one_hot(indices, num_classes=vocab_size)
    return one_hot.float()

# %%
def sampleLSTM(model, hidden, cell, start_ix, length, vocab_size, ix_to_char):
    """
    model: Your CharGRUOneHot instance
    hidden: initial hidden state (shape [1, batch=1, hidden_size])
    cell: initial cell state (shape [1, batch=1, hidden_size])
    start_ix: integer index of the first character
    length: how many characters to generate
    vocab_size: total number of possible chars
    ix_to_char: mapping int -> character (for final text)
    returns: a string of generated characters
    """

    # We'll store the generated characters' indices
    generated_indices = []
    # current input char index
    char_ix = start_ix

    # We do a loop for 'length' steps
    for _ in range(length):
        # Build a one-hot input of shape (batch=1, seq_len=1, vocab_size)
        x_onehot = torch.zeros((1, 1, vocab_size))
        x_onehot[0, 0, char_ix] = 1.0

        # Forward pass (no grad)
        with torch.no_grad():
            logits, (hidden, cell) = model(x_onehot, hidden, cell)
            # logits shape => (1, 1, vocab_size)

        # Take the last time-step => shape (vocab_size,)
        probs = F.softmax(logits[0, 0], dim=-1).cpu().numpy()
        # Sample from the probability distribution
        char_ix = np.random.choice(vocab_size, p=probs)
        
        generated_indices.append(char_ix)

    # Convert all indices to characters
    generated_text = ''.join(ix_to_char[ix] for ix in generated_indices)
    return generated_text

# %%
# Suppose you have:
# data_indices: a long list of integers in [0, vocab_size-1]
# vocab_size: total number of unique chars
# idx_to_char, char_to_idx: optional for sampling

model = CharLSTMOneHot(vocab_size, hidden_size=512)
criterion = nn.CrossEntropyLoss(reduction='sum')
optimizer = optim.Adam(model.parameters(), lr=1e-3)

seq_length = 25
pointer = 0
n = 0
max_iters = 44700 * 100 # 100 times pass the full text 
smooth_loss = 0.0

# init hidden state for single-batch
hidden = model.init_hidden(batch_size=1)
cell = model.init_hidden(batch_size=1)

while True:

    # if we near end of data, wrap around
    if pointer + seq_length + 1 >= len(data):
        pointer = 0
        hidden = model.init_hidden(batch_size=1)
        cell = model.init_hidden(batch_size=1)
    
    # Grab chunk of length seq_length
    input_seq = [char_to_ix[ch] for ch in data[pointer:pointer+seq_length]]
    target_seq = [char_to_ix[ch] for ch in data[pointer+1:pointer+seq_length + 1]]

    # Convert to tensors, shape => (1, seq_length)
    inputs_t = torch.tensor(input_seq, dtype=torch.long).unsqueeze(0)
    targets_t = torch.tensor(target_seq, dtype=torch.long).unsqueeze(0)

    # Convert input_seq to one-hot => shape (1, seq_length, vocab_size)
    x_onehot = indices_to_onehot(inputs_t, vocab_size=vocab_size)
    
    optimizer.zero_grad()
    # forward pass
    logits, (hidden, cell) = model(x_onehot, hidden, cell)
    
    # shape => (1, seq_length, vocab_size)
    # Flatten so cross-entropy can be computed:
    #  => logits: (1*seq_length, vocab_size), targets: (1*seq_length)
    loss = criterion(logits.view(-1, vocab_size), targets_t.view(-1))
    
    
    loss.backward()
    optimizer.step()

    hidden = hidden.detach()
    cell = cell.detach()

     # smooth loss
    smooth_loss = 0.99 * smooth_loss + 0.01 * loss.item()
    
    if n % 100 == 0:
        print(f"Iter {n}, smooth_loss={smooth_loss:.4f}")
        # Optional: sample from model...
        print(sampleLSTM(model, hidden, cell, input_seq[0], 200, vocab_size, ix_to_char))
    
    pointer += seq_length
    n += 1
    
    if n == max_iters: 
        break
# Out:
# Iter 0, smooth_loss=1.0426
# m,rmdF&Pg!AR;?fJ?wazXtMFnn$&KZzmdF!kj3&;BByxVtYtFtGg;T3,fF
# Qi3HVrQ$ULE:eP
# Buv
# V$S'zwWfy'KwT!VKLejEgg?kpKHhpoGHDGEo!;xwkhQ.Dgjwuj:KawjLnvkF3'?P'jW ag;dJKiXq?geTmavW,;VQFi rEvE;x$c&W'CSVrUphuEtJ?NXHijo,
# Iter 100, smooth_loss=51.8650
# yeii 'h:hl, s h
# zm
# nrt  nh as.Wn
# hesEcs  z
#  :mao e snhO;npsatoa hetn tsaIL nhmn:p cTss ka,h
# t
# m.d o ehvtohyon! i mhn
# bsvfW weCoue'  so h,.iy
# eC!
#
# t eaohn ynaluvtCY'Fslt? igcano.mw e
#
# e t r oco r
#
# Iter 200, smooth_loss=68.7032
#  lthd td iuem, EtsnrSjnanru ,eiTust, l aoe iowukhi:Ht:hmbicn !ortinWbm, vioytshy ouulr ar h
# aTuoe,tuyln,
# hret
# uowtob
# .lo
#
# rrn Itue oli tCis nol ati
# g-,
# ydcIsl nhi mb,lvertsl neep
# oo yit wedr gee ipir
# Iter 300, smooth_loss=70.1024
# s sfEspSye puwmmer Doks fosit:r.
# Le
# Taes
# ghok thh, foame whit bho belea wimgwbes ,iri? wasg, alaoo, wacs bus triae man? anet houe ar cirsr WofrNI
#  hinc toug rau' sosb bous,lo Foonns
# lhlo sgobtap
# chat
# Iter 400, smooth_loss=67.4858
# nno nsec thiiN- ghes
# Wheig bosd the rse toogtWanenlthate, nrint boe -rt sulos ied bacid gheuA the mor ffig.
# Thatils theme,
# AsS: MMw:ISI
# ANS
# I-:SSUS
# AU:SI
# IiS,USA,
# The theioid tham the sMdr
# UTbdr theuc
# Iter 500, smooth_loss=64.4774
# afU.
# Th thod a hi ther ad therm
# Sas?iths:
# ins tho cildeSs asr
# SC hes Sol
# IUr mo to be Oo fhes hit mes.
#
# ERNRTISI
# Beidion helulnld che gerd hrs fok. the wf ni Anun cet'c The rron whileslt ge ch tho co
# Iter 600, smooth_loss=62.9818
#  you woul!Wilk elver;.
#
# She wo hes norerelcelnim, on s'ncom:
# Fheuut:.
#
# OArs youg cose; amn ane
# Ond.
# Harene pe!
# II Ched htay feee the fante bsad epmy fhete. fow ame goe  her ous I whe, 'n stou ide.
# Wei
# Iter 700, smooth_loss=62.2731
# he tey wo becorg. hernHW sy tour!y: so tourheknser,es, blcare. sin; a'uff, hire.
#
# VRLIMUNIA:
# IA on byou! sor
# Hiun rcounr hos hay foumd goay!a hour,
# goon, sor ratir ee snelthelny,, he asdyee thand!.
# he
# Iter 800, smooth_loss=57.3027
# hemein theed 'st mameuul,.
# Sere ig.
#
# Muss ySathed.
#
# MARLI:
# Ln. grethters thithe o vevan:
# Futh wavey,
# I thle ou:
# wisg as:
# Womltion.
#
# LARUMUS:
# And srely,oe !our your cer.
#
# MAnos wawas eed thrs; thet, wi
# Iter 900, smooth_loss=57.0455
#
#
# Aur Non aurs wirh fi,skalld the cikd lorss:
# Thiesn.:
# Flerd srucer,
#
# Let.
#
# Silto At wh nlrin: fol hiin!
# AS:
# To Tit,
# Wilds slathans:
# Sorses th, ird ves hir oB alld the rkopeesster:
# The gial;
# Lore yiar
# Iter 1000, smooth_loss=56.8065
# s hith of thin'f doul karsd'siesy I lpivede.
#
# IAedeant piuid
# Fntat.
# poRCIUS:
# aroy tiogs
# WhOulss saf
# culciusiaive,
# sou to RomaugE
#
# MrsICI:
# Merse,
# Aud cikintgith seiven:
# Ses uuchiben!
#
# Cirys Sinp'wen.
#
# Iter 1100, smooth_loss=54.1491
# Fat have thail litt hagd the mangertiwith-ed ofe dare
# Satand to tour thes. Whemhithur bard thes done withe waye q' costy zould are.
#
# MARCIUS:
# Thare yout eupser,
# Theyhd
# He te hed arciy thu, ot waveidid
# Iter 1200, smooth_loss=54.1784
# nathin, have soshe ke Cleladog;
# Ond aen shash sud, wrwe'r lthire the the us urt prabe thour gutees thas le semiret,
# Sath your doavish,
# Whiar fhade maddm:
# Thou d
# reard;
# Mare Ruthell Crith anp seroud wi
# Iter 1300, smooth_loss=54.6650
# all Mall her halin's LoSead, WaNIUS
# IUSOAUSUG
# AUS IUS
# NiA I ASLIAUS SaO'IUS:
# Gis palh, Thamkfs
# Ann,
# Sof the s!ASISS
# Afd AfdeIWILTOIS:
# IUS, CORIAUSUSIWOSules
# Chuplaxf':
# AOTIDIUS:
# Thenh wich.
# Wow a fac
# Iter 1400, smooth_loss=54.6380
#
# for hoy whher got an in tolly houcd it, Fey og thesd he 'lr paar, mise thl chis he matiuss wo latts?
#
# COMIDIUS:
# Bolc at they bulr gaese on tre diite und not; nfred un nf nold and whal hiver, the pria
# Iter 1500, smooth_loss=53.3041
# athe sed tris the ranow spabutt of others your
# the bant angrist entang
# and and mn-alw towe re
# Barn wine bningr wr that plomt.
#
# LICINIUS:
# The zron wasing, mayialr you they cood o eneceudiw; ve cbvitian
# Iter 1600, smooth_loss=53.1949
# hast
# poushe,!
#
# ROMUMUNAA:
# Wo asd of thoust
# feor wipmsaes whe
# ming my. She gome u daes tank taand: whas, thond:
# Of im hoot,
# Hun'ing peiess,
# thoige fole-
# RoSd-Live alp!
#
# IENINIA:
# Harscone,
# Gomiand worei
# Iter 1700, smooth_loss=52.0169
# ncave gralet!
# Wekciun, yends Hy gopered,, whrrmus Wontraws sin.
#
# VOrLINAA:
# Sy wols siis gatU
# higl- wride he parpion pritisiditis,.
#
# VOLUMNIA:
# On cibe, sa'ad has suve.
#
# MOLENIUS:
# Se han vacl, Onerer be
# Iter 1800, smooth_loss=52.7840
# rund
# Comser'loven so doem's,
# The saprovarf lats,'ce nomer nam! is lhows ly y
# Mallecs ofprod: whipne orte
# Whar the bey: corNCant ho pumEthaw horlavy, set, my peareg sla
# And
# he wimp snebdion opf bracaes
# Iter 1900, smooth_loss=50.0649
# ; wellde,
# Mnce
#
# Seed held peoblame- theur, stey and
# Tote han sacatren heers hise to bucare theius,
# At orlame paver and marloune swer.
#
# SORUTLALUS:
# A onuores a's enlore, toms,
# Dor youur set; conoury-sh
# Iter 2000, smooth_loss=49.6789
#  latit.
# Hontre of the Uy hand
# Menkoul, ho meprect me nour wounds;.
#
# SRIToS:
# youw
# The werk thilk codle here, Cof, pet it.
#
# Firss our bolere
# CoBiuls to wither hive rave
# And beaony somine
# On nommaous,
# Fe
# Iter 2100, smooth_loss=50.8450
# R werm mins it thim; of in Ceiilo-un re wiglbn ofod:
# Gemapdis kpand ave he plaraus an beisceid jimow: ard eike thunk, sood
# Wordt be sionnusserlen.
#
# CORIOLANIAnS;
# And nom.
# I witusm chos, mastuess everg
# Iter 2200, smooth_loss=47.4839
# s is. You he hom we led wispenes in in sfile?
#
# MENENIUS:
# Lucule I moyes The mise: if thic,
# Them?
# Iterder hive
# Them suall he sintheur: to you themm or Coniot:
# To key quburt- ro iopills!
#
# BRUTUS:
# Go pun
# Iter 2300, smooth_loss=48.5795
# aruonn; ham; dand
# Hike houghivy
# Nhink; ans tousr beworat
# Youg eroyeon con
# Thyy malo, then, they nudele?
#
# OLINIUS:
# Hese, whind
# Ofourt him we more wall
# In mincous, burt th mush fyou lottor band the pabe
# Iter 2400, smooth_loss=45.2088
# your proy nobce ofas meid sose, shaslry is and 'twercoms: yourew
# Your
# byow to ouk sound.
#
# CORIOLANUS:
# Fornge thiir fitch, fourtp of fracit.
#
# Thild Citizen:
# Soun Cist, and the gome Pobbe h asted doicun
# Iter 2500, smooth_loss=43.7911
# the people,l, shoinds
# These say, one lost, and, he dave mis?' will we mos his moctuds.
#
# BicIn Sit:
# That mois peicn'lud,
#
# he his not he, so mank. I as mad tas st'bu hac has dis wound of he shound wound
# Iter 2600, smooth_loss=45.1394
# y comyer flrefuntiand ale heop hess all thene him yen;
# And hid nuxclile them port, and thougher som: 'emdhe' futenss lot of; rod apereid rove condom.
# ; them conpeops;
# bot our'es shornow your ofor'yed.
# Iter 2700, smooth_loss=45.7082
#  a? wher the pouther?
#
# MANTIOLAN:
# Ay, eors fhit my aukert his mor prirst'm ads word,
# Bnwer heid be.
#
# LARCINIUS:
# Fe as us Bove ondirufor. je pariyitision.
# Sthid, diy we he sagl of stiinnt
# .
#
# CORIOLANLA
# Iter 2800, smooth_loss=42.9008
# f them bure your him.
#
# CORIOLANUS:
# Thim res mas o' with ast
# To think wad noll Gas comm.
# But camm ky you ware sret is if ames,
# You noble.
#
# COMINIUS:
# To lave wiy piash hit;'d.
#
# COMINIUS:
# Now nok louth:
#
# Iter 2900, smooth_loss=45.6575
# e bes your mapanser farly, ho in it they
# The zure the maree, LMakes we cobne by, vosh that enatite
# The ces o' the kere as to grake,
# I swall! not, afaite;
# The vanate
# A'd-s e base me coreey
# I plond.
#
# ME
# Iter 3000, smooth_loss=46.2802
# , should ean whith rekselted'des.
# Not they bewang the Gonator, ancu
# fat I the hedpein thein the hemensedt-ly not,
# When for then then was them whet'ceicl besttervt, them no forioun thes!
# What you your
# Iter 3100, smooth_loss=44.5368
# cinans
# Te'grif.
#
# BRUTUSrelt
# If themriin,
# Here of and corthel him;
# All most seitors diand thes,
# For yolg lon files.
#
# BRUTUS:
# Fere: all co?,
# The pureosine fill, herpore areing mumt to treice
# Bose usend
# Iter 3200, smooth_loss=43.2133
# fe; visi'g the sear.
#
# MENENIUS:
# He wouldo him, boathegs: 'Ciyies,
# Waw, the peorle;
# But with this hould ane ip utfong!-
# Mews giner- preag
# So'gucy be done!
#
# BRUTUS:
# Ylollue froudh ir frood
# Dag him histl
# Iter 3300, smooth_loss=44.7566
# r vasere:
# I to Jund you, peind of wh the houstly?
# Latt'er chall a wore wher; the a Aungre
# Esust bate, thrivessGoce.-
# MANENIUS:
# Whill wil,. I do; Marksth:
# I do the lor a proved menusetiou, to bet
# and a
# Iter 3400, smooth_loss=42.9037
#
# Then -urtry them to;
# Comisors, Calius.
#
# MENENIUS:
# You nurutt?
#
# CORIOLANUS:
# Ceay, paics,
# Is alling the hight.
#
# AnMNIUS:
# We, when out them!MTSid that wound ferbuth.
#
# VOLUMNIA:
# Priin not be deserfito,
# O
# Iter 3500, smooth_loss=43.8523
# Aseing estigitian.
#
# VOLUMNIA:
# So lithe wheir difmhhoo, andie-thou hastlow
# Thy ecton plower
# Here it, whture it fort, yat ass they,
# ? theire, the ardnefipseent pewer: ward, wielp-jy nablinc
# They bulk: a
# Iter 3600, smooth_loss=44.9790
# ilg such before, asclesine at me prenst ding
# Thou has chor me not do: thuf Trithor bulcme, ard alf
# Trich of I mirget hord'ss, our dest of them ad the and in uneny.
#
# CORIOLANUS:
# Ourael us me have hor t
# Iter 3700, smooth_loss=42.7377
# s net pustiser..
#
# IEdild:
# Cominens, all!
# No peace.
#
# CORIOLANUS:
# Heas, well, Coiren:
# I' you are greante;
# Nand senceiter to has begir.
#
# AEdile:
# Well ke him.
#
# MENENIUS:
# Jirts, shalls he sondon thee are b
# Iter 3800, smooth_loss=41.5708
# er.
#
# COMINIUS:
# I shall me sachentel; amawing for geare
# Leedpy comes e can yimhoo not thou prayice, sood Romess
# To alawine suke and the parsion.
#
# COMINIUS:
# O, conerin consuln bn is mand for go the peop
# Iter 3900, smooth_loss=44.1841
# ! Marcius wime say, I won'rave it mened,
# Lyave flead not feace trlater
# aton trritures woml'c;.
#
# First Senvening
# Hod, no caure: sany, andion!
# For'ch, seingens hom! nuths own grre,
# Of me used holatuon O
# Iter 4000, smooth_loss=42.7330
# IUS:
# Ane nisI for heasalg their toushour crechoritate: areiy
# Thou gods wither mor.
#
# BRUTUS:
# Thay feand be mange' le fould to than, and agient son.
#
# VOLGILIA:
# Ive, bes'ile nower of sose.
#
# BRUTUS:
# Mothe
# Iter 4100, smooth_loss=42.8354
# y I canger. you so nothile is courping. reing thant you unangone: kt feath is in your hearteithy my you gray,
# 'on, then flom, see ade that's in upnourst's te aufiin will dere you fall: my their
# sir ga
# Iter 4200, smooth_loss=43.9239
# e mouthgy, whole us,
# whose fime osfer.
#
# CORIOLANUS:
#
# Cithy lither, whose forte'crions Inweer, whos no good
# Ancelyslemt.
#
# CORIOLANUS:
# Hereese fray to theset his Jutblects bapons,
# And thy, ardsiles, fer
# Iter 4300, smooth_loss=39.3748
#  I'TFAndASUS:
# Pray: no coodfurs!
# What man sworts, my with the stiter fok.
#
# TiRUS:
# Serving? getleor?
#
# Third Servinguan:
# Henoke beoce as you
# plate estient,
# Aed you and stull opt at, hhan her his extle b
# Iter 4400, smooth_loss=42.4543
# o thee not.
#
# CORIOLANUS:
# Prome, Inky who, hith mery, scrown forting.
#
# Third Serving trust And Wling.
#
# A Fivan:
# A mnarance: If hellly of that's exver
# blood to thre speak dood to that
# I' thy deen unfer
# Iter 4500, smooth_loss=41.3822
# ree
# Thou wild, than lan it is recingest!
# Pyonan wal, sir.
#
# CORIOLANUS:
# A fare them here caln fier to yet my bay.
#
# ARUTUS:
# hem, you he gore not takn
# I wold dave hemenemy deakur my swendple his holf In
# Iter 4600, smooth_loss=39.8975
# ois filgtermel qunselly fitsts of as
# antiens,;
# His patelimals it daeswes, of thry this, eney labfrestais;
# astin, who, hhil, I'll kant then: bursion;
# he
# thonget it bus thysel's, sur sevse
# Bun now say a
# Iter 4700, smooth_loss=41.2026
# ll las the pristhed you all.
#
# BRUTUS:
# Nave's nether.
#
# BRUTUS:
# Where! ge'dow's shall,r?
#
# MENENIUS:
# Hawave to do your traius Sace, and
# Withing, and.
#
# SICINIUS:
# Misen mither.
#
# First Servingman:
# Have Comi
# Iter 4800, smooth_loss=41.2108
# th no' these have Rome;  upon sifsreny to tumhitoAnd,
# Bud Auding your worl'd.
#
# ScingNAUS:
# Thee! Sie, in Maisiun
# Rumman iblee is sore wakeir hame
# Hore bathith for to-d
# for, mike atnerply freatious
# Cana
# Iter 4900, smooth_loss=41.4043
#  To so.
# They we drand for vike otterse
# As it?
# But worch going.
#
# COMINWUNUS:
# Afly, but Pucus?
#
# To consur:
# Whe rave! he leest follobe's wroar make aifoo; frack you shay
# Dow poril to bees a shaked the he
# Iter 5000, smooth_loss=41.6513
# iuthul; and chand into-rishies atal?
#
# Mieiter:
# And noble berock ure anciyou him, and wloovy
# Heandly it as if I could we mare youchiert
# He are we howf wethis tribunes'
# asfident'd eary are of than arech
# Iter 5100, smooth_loss=42.3939
# rild:
# Le no buor, unte ad the wids hath you
# To the hasp a madus fiad's so frild: un, that
# gown if that has pait? What we well witht,
# Or nod of breag his ponbless like their peace;
# and shoethy are his
# Iter 5200, smooth_loss=39.2864
#  rave upover, time
# A fess wit, ton, bent to your wassor neaver
# To before to, as Rome; hath his conniof.
#
# MENENIUS:
# Pray, pation the good off
# To nake off. And pray with to go;
# Inlo distore lood then al
# Iter 5300, smooth_loss=39.9918
# xvice
# of thoush now daesin, afferink of your taguiante awatition
# swolknt of that, and tall so, ruth fortune.
#
# Flord Senato::
# So sithy to my noble, I thou -ay,
# Criald, is our verraviansefnes under as h
# Iter 5400, smooth_loss=39.9746
# sprck: by raught
# him a go!
# Have asyigies.
#
# Second Senator:
# He the wand within worthy in dosidge'ted,
# Inle confered leanurinrby, thene assainst
# If: wull indrestler should frue set furethy it.
# Caire to-
# Iter 5500, smooth_loss=43.9887
# The greaties?
# Nay,
# My surbors liad the? your  angrrim thes; a carres
# and powers your-ofter
# Than not than not very gods,
# The sungors your harraty; is me.
#
# VOLUMNIA:
# Aklow, but,-dher of but leaved
# Than
# Iter 5600, smooth_loss=43.3948
# ! ow no, god, who heer us sorwol
# Fof say thou knot enest.
#
# VOLUMNIA:
# Ma, childs.
# Ale prass you deny not twe with frow that, but,
# Our remoways,
# And provay I most well, and a wil; to we howsing uncrur,
#
# Iter 5700, smooth_loss=42.7695
# ere all to he was. Thought
# you with cun you arroobl our will sime
# And will no would to comest plocesians, for with was than popsiagat's
# And you man the many bestn un mon Rome afeis loves, thes. Mark,
# Iter 5800, smooth_loss=42.6117
# e you terrwen he cast?
# SI are we hach his puagl carn with his horsh betording
# The pinfite-turr reese.
# Are to calk yotr shold than to malint he wind this mone,
# But the Rome; and his fearent?
#
# CORIOLANU
# Iter 5900, smooth_loss=41.4749
# ianss, ard us- That lask: and doop that Marcius.
#
# FOurse IThouds unso heard Wride
# Of the general.
#
# SICINIUS:
# A: here them:
# Shelto think the wascomsly there thruins doem's toget in the chraguts them
# Sh
# Iter 6000, smooth_loss=40.5054
# ll gond denerance. Guscaning,
# 'T, throokn remen, and loor,
# Sall not hotsoss his polbor known. And pown;
# his epriment angolslan, my chartunce;
# So den jore afang wordn as as sarme tumpplied
# Whe chaining
# Iter 6100, smooth_loss=40.5719
# alt his busting
# I a rolb trovess god a't that you too- ke has mothe uabts!
#
# AUFIDIUS:
# Ay my bere gave, but him farspess no wralls
# And crefais that speak in that
# Your not, for my that is I sam outh hom
# Iter 6200, smooth_loss=43.5767
# lg oin 'em this sookurge.
# Yould mours.
# Helad or ble:
# So so in the true alust,
# Of upsater'd my sands o' the struids
# Our sugon, say'sts peais and counter
# Of moved
# That mosust thourd of surn weatiscanie
# Iter 6300, smooth_loss=45.3451
# NCEUTESTER:
# Of I
# Of that site lodged by with sinCes,
# lome, to theightateding hI that bl cons.
#
# GLOUCECTECTERTERTERCEnCiLTCSo
# My not!
#
# CLARENCE
# As I ledam!
# Has ho throw de, 'y to enter is I be licks,
# A
# Iter 6400, smooth_loss=43.3935
# tho agey to do.
#
# GLOUCESTER:
# You are I would coult it king,
# Hear wink by in herefore theme'd the meutque interrot
# Well me merwAint. Why,lloaes sender it.
#
# GLOUCESCENCE:
# I what prayne mase mer, were th
# Iter 6500, smooth_loss=44.2441
# h eld hes this baid.
# 's must necg his made the endot of you gatter,
# Mosss thou whathts the gods of that thast that had this bvoner this magy
# Obur one hyaltslefant thou nawe not the Cursodity,
# His nabr
# Iter 6600, smooth_loss=43.7283
# ghen I pown, good kech
# A foot, but anding, armade his mordatheril'd.
# And whint chade thy pack, as news, stpright edean dood. I helpy you have!
# Brovty I killques I cart? Cuar, he this pastan morth'r ar
# Iter 6700, smooth_loss=40.1581
# e.
#
# GLOUCESTER:
# No leint untoo bloody aspeit.
#
# GLOUCESTER:
# Whkse you badd dever the , you seln: comming-Tongerse.
#
# GLOUCESTER:
# Take, mad to faur!
# How re me of shalder homamk in am.
#
# LADY ANNE:
# Frilen
# Iter 6800, smooth_loss=39.6646
# ar my my adbe to we,
# I beel vyel moving heaven like youn o' the peace their Rearss;
# Mike it by comes: sreak sthack be;
# like sin tell,
# My sale.
#
# GLOUCESTER:
# And Beend, tool hear?
#
# LADY ANNE:
# O tibe, sw
# Iter 6900, smooth_loss=38.7577
# fire, for there-kn by cannot brood;
# And Passernow and liksee the shood'd most of our nop;
# To found some with of mund with this paul infectern.
# My live her infection thing forgady,
# Wo, that in the red
# Iter 7000, smooth_loss=43.7611
# f gruces But his one as eintwy dest'd sen the hume?
#
# HAVY:
# Yeart, you shall. Praitors, secher some the loved and son her I did bort.
# For our grace so these have beself akay up arr minot woman?
# These'
# Iter 7100, smooth_loss=42.2988
# oks, graked.
# Tinch they he hapt love it, eovilions;
# And your wine wink now baty, stand, sor, detwer:
# Take hery, ere a con,
# Which of a unju these breaksery.
#
# EUEENTER: Gow, and have kill your manaly:
# A
# Iter 7200, smooth_loss=41.1355
# ain,
# And reserding to with account tencle.
#
# GLOUCESTER:
# She, bet, your and, that silct you,
# To better, hersh kis brood coker
# His rrisband of than heith, at your bysoe to heave,
# That deep of thus heart
# Iter 7300, smooth_loss=40.0500
# isht the hated laed you birte and
# yet the world, sad is did acond conment arr:
# And Ko, wouldroy your a blood enjoy enjoj.
# My 'GoElabgod tLeely fasself now thre, and o rtseech the should.
# Auquading-ow
# Iter 7400, smooth_loss=40.3946
# thy hearn!
# Thou, state nor naGuds petning of that me?
# The' Jack thy enri'irs some,
# MMfathEM:
# Havishur thy grow thee,
# That is I have friendiiys Dos my lorgly.
#
# GLOUCESTER:
# Hear not the death, you devi
# Iter 7500, smooth_loss=39.9825
# t.
#
# QUEEN MARGARET:
# O, to de's marry and your glain line
# Takes cuandain shame engry thy cleese in.
#
# QUEEN MARGARET:
# You blushies with mawhath welly on caenith.
# O, ale they donely live well me!
# Leaps t
# Iter 7600, smooth_loss=39.8691
# od detter my wade whichs
# And which serve for yat this death,
# As our hation, live alven you their arewer.
#
# RIVERS:
# By Guither I mr.
# They closest will were it sean, In the queen of whom Gress not the wo
# Iter 7700, smooth_loss=41.6984
#  my, what less,
# But where in the gows thou artion of proped digh,
# Fow he wathes the forns bided of Peaud frouched;
# Nor's my compaighk and, stere it had not world,
# O, be would arghblath of strank and t
# Iter 7800, smooth_loss=41.0243
# My gon I have fiend upteriend hake thim.
#
# BRAKENBURY:
# I
# Made knood my sorrow'd him: the would sworld kous, ble to?
#
# BRAKENBURY:
# What Was a cuuld but our grury'dful to angerbend to I weal.
#
# BRAKENBURY:
# Iter 7900, smooth_loss=38.4792
# n Back to thee a world, Sake are consull torre
# Tone their ontencain namest good cherberbant usjeccolies me.
#
# Second Murderer:
# Ret'tis with guils the math, it outs come, it
# is I slirfe detutuwotin mrea
# Iter 8000, smooth_loss=37.4596
# -
#
# Gond Murderer:
# and huse from fow trust?
#
# CLARENCE:
# Well thou lives, do kill he do to that God do and eyes
# Nordeaves nos corman to, soodhe a bures;
# To gowart.
#
# CLARENCEBW:
# Shoulded he shame unon me
#
# Iter 8100, smooth_loss=36.2020
# ow of his thires,
# Thou will doee in this Sins offel, to will be trust with beer.
#
# CLARENCE:
# The manded he fot that I so.'-it you my new jone to us.
#
# First Murderer:
# Do.
#
# Second Murderer:
# We commandus,
# Iter 8200, smooth_loss=38.0018
# rol husbous,
# And will him twet is fithee his knack;
# And you are more forerech to heart.
#
# QUEEN ERIZABETH:
# Well, soAr thou dand' you, are, so, is helithet.
#
# BUCKINGHAM:
# Propethands and brereca,.
#
# GLJUC
# Iter 8300, smooth_loss=38.1881
# la, is jutisy.
#
# 'INENG EDWARD Hors!
# Where our doth noble deed
# of shall happgtignoo lamely;
# As I have senarred alange his berged to killy,
# And to currial I love: if if upfiglmies hatgech me;
# And, for u
# Iter 8400, smooth_loss=39.9950
# habd and in cold,
# And fruth gran soul that you weat not of you.
#
# KINGSS:
# To bethen lovady my soul hear,
# Which say Go devisebreast love!
# Who I had in his flay in paach of him.
# His whin his wring? do
# fr
# Iter 8500, smooth_loss=39.9356
#  were likes, and me!
# As littlet your grand-m, some it?
# Hapk it. No, and by
# OD,
# Yet you my precommand: nhe folmot of equaces:
# For whith he princeld in the were.
# At to hispurt not our gut bidkments, I h
# Iter 8600, smooth_loss=39.2069
# emtaim redtcheesst
# Myself an the untoully in Geece
# But knep tell vight can a disbuly.
#
# BUCKINGHAM:
# Glouch of gone.
#
# GLOUCESTER:
# When so much I in my Clipligunely's kone
# At I seint, the cliving survedt
# Iter 8700, smooth_loss=38.1286
# be myself, in, my soul, Three your breach!
#
# First Citizen:
# Madam, I am are the king-fet,
#
# First Citizen:
# Ind midies sowf! Myselves less well-dy us;
# If ichibling you.
#
# GIRGY:
# I diret go.' I for Cliper:
# Iter 8800, smooth_loss=38.6379
# him,
# I haught you, he among with overst your not breaj.
#
# Third Citizen:
# Ay dedime, I kill Will ke,
# Oblow is the father to be ax sifterings,
# Is was long, and Gtroth heartrt,
# Restine they, my UdNCright
# Iter 8900, smooth_loss=37.6675
# ou hild;
# I love these, no: malr can, our ceirs, if the feers and was loaks alaidsts;
# Their glanther of him sinch in,
# End in a mastly time to soffer to did an arm to For
# Bouns of goan to afects twe ki
# Iter 9000, smooth_loss=38.5392
# after of your grace
# Us reaby me, I will duaningly and to crose, if God entuke.
#
# DUCHESSBOO:
# More, my mother unsweatoes and grandouch; look.
#
# CUTHINGS:
# What mirees yet, we gracious, then you wert feefs
# Iter 9100, smooth_loss=36.4557
# d'd die wif I
# In Rome, my plooding qurerie, whis you lessred York
# Haves cother when I'll gentle my liven King.
#
# BRIKGES:
# Good till it now is our conVither eFpt of Tiel;
# My sancturrs since were wit his
# Iter 9200, smooth_loss=34.5797
# ar a dost sorrown hours.
#
# PRINCE EDWARD:
# You beat would do be once that fartd,
# No more ent you little gown?
#
# GLOUCESTER:
# Wear.
#
# GLOUCESTER:
# God for what mer yor walls your grandam,
# Merelp on you we we
# Iter 9300, smooth_loss=35.8914
# y: the sucts the bitience!
#
# PRINCE EDWARD:
# He me. And, my Lordon,
# Azasorr his brotherpively: hambly cannot not full him so.
#
# BUCKINGHAM:
# Whom was councles platesting this?
#
# ,'stnYger:
# At it ry vorce,
# Iter 9400, smooth_loss=36.1859
# re, of I dear them the toulf
# Towmord him think'd make mine to may your friends
# His earlids the Duke news,
#
# CATESBY:
# I'll not spare place is distractle kinglyer.
#
# CATESBY:
# Hour York ou meen the Tower m
# Iter 9500, smooth_loss=35.7793
# dions one, indection,
# But then the priest those than is me eect him spastle tere
# Than I mest this Learidation, Lord and thei, my soal since;
# How no shrow the mastersny.
# But at thing to morn good to di
# Iter 9600, smooth_loss=36.6543
# sign:
# Then some this loves!
# Wih no your cracb'd of you?
#
# CATGS:
# She I do laty thereefpy.
# Take pirfars, he more creinous but lives in why
# Fie neving in unon tauke,
#
# DIRHALLOUCESTER:
# My lords, and He pu
# Iter 9700, smooth_loss=36.7499
# owghd by thing him as thackle forlick'd
# Their from form they,
# This purt witch, unlooking my long;
# Shall poot who bear spram me
# Thom swunde may pasted with botadt you she
# To-didargestiend berombinsts;
# Iter 9800, smooth_loss=37.6739
# kerbard'd with plogs's, prince,
# Which,, the sayees! qentle dited now.
#
# DER:
# To-drawn pity of troish.
#
# GLOUCESTER:
# Catesby wait menser--
#
# GLOUCESTER:
# He dail a comorreatire!
#
# GLOUCESTER:
# for I head hee
# Iter 9900, smooth_loss=37.9453
# ends:
# Book your gentle timed his house.
#
# OUEY:
#
# GLOUCESTER:
# Hast beturn conclat, uncase hands your hreatleraunlisgrand's head of this sup
# Tray give the look'd me gover to the pown,
# To loult of the rea
# Iter 10000, smooth_loss=39.0779
# ezit conoure this reath,
# Dead for me will will smemperied biching and the yov;
# Here cannot yet senitse, by deathront.
#
# BUCKINGHAM:
# What is than everaind! Bystgent;
# Indowned hit te man the sugity for m
# Iter 10100, smooth_loss=37.6685
# deris desardum ward be gaw I pathers.
#
# BUCKINGHAM:
# Withend, to fair show my lord;
# And not can trait wistoly natier adtence?
#
# BUCKINGHAM:
# I take you not were truited to fizess of hands.
#
# GLOUCESTER:
# he
# Iter 10200, smooth_loss=37.8076
# me no being God for and rromping:
# That ssook's thou mean to my book themshons:
# Which fall, but in thir ward: thereI
#
# BUCKINGHAM:
# I should him joy of your livend sippey fear
# Saccan once:
# Was ell in by
# Iter 10300, smooth_loss=39.6632
# rd!
# By botler that I shap mine you and meen to Draw to end.
#
# CATESBY:
# A'd who's not make, to-Lust with not struth speak a hand.
# And revect of be noble masters abowers,
# But devenion: again when eary br
# Iter 10400, smooth_loss=36.6339
# e?
# I am I move you excest the plarm in fromity,
# Go to amoths our kwaldhy is duriot:
# As thereafful'd bither at Od witcihe of Those.
#
# PLINCELY:
# My lord Love or law, lady: Beaden this sire.
# When refond o
# Iter 10500, smooth_loss=36.9390
# er, he broke to usle bleave.
#
# BRAKENBUPK:
# I titort, upon here he shall gatate, then he chee- intemder?
# Here if ted ghouthuse repure, here see.
#
# gLOUCESTER:
# His bearnt thim: I'll pusian, houring the tu
# Iter 10600, smooth_loss=39.2493
#
# Even mades and lives the sturbt looks,
# All to the ableries that, keet us all,
# This duscupation short sillw and otor soul!
# A fall for all. whose to, motidants!
#
# LADY ANNE:
# No hour becoeds, comet the c
# Iter 10700, smooth_loss=38.1793
#  divrom to give?
# For he lord, good but to the Sturn's barcthend this
# Your hands, be them is say, By you merce,
# All ge to My gentle's sorpelh;
# And do I have the high hacss thy sinness.
# Yew-come him bit
# Iter 10800, smooth_loss=35.2952
# cuuse, no, kill's vome,
# And you else I have so feit you thought yoor king!r
# What stard it dost a itor of His gravious, siff I hind
# Whattise back the throess'd the capvomered.
#
# KING RICHARD III:
# Whose
# Iter 10900, smooth_loss=37.3471
# troke your friend desire
# To you felter the king od, of Marry slawats.
# All thou? should was proph, or all.
# Therelow I sue meet back'd 'two joth Greenan of loving?
# May rides leave it Do be deed.
# Ungivit
# Iter 11000, smooth_loss=39.7508
# abauming such thou must right,
# And a king's brid to-.'my wearw-
# About dief,'-
#
# QUEEN ELIZABETHHABUY:
# I'll lammnayhe hatt mh whing your morsp tongue edward
# The field inour done cannot's ding's jues omd
# Iter 11100, smooth_loss=40.0247
# ng inceusite,
# That forge strake hander, slam my for would draw, hors,
# And the Trieur of the strown, Rully thoim aged other!
# Pain! I had be the holl of Richard,
# A dance that Jlow, then then live chand
# Iter 11200, smooth_loss=37.3900
# his name.'
# Aharfwill throng Richard will we RoRsh formaget
# Unthat should one troubless, I am dight to that thee, the wrep!
# Commores well help ambhathery heart,
# Hept grave what thou of this nemd news;
#
# Iter 11300, smooth_loss=35.8952
# prry hard'd one ammnood.
#
# KING RICHARD III:
# Demation, mother one toech gonefuls.
# Book onk thy -ages, and furuson.
#
# KING RICHARD III:
# Wife, may with this thy compard fet the cause!
# A wift with excle yo
# Iter 11400, smooth_loss=34.7570
# us nold will thou would.
#
# KING RICHARD III:
# Thut, on too, my endlers and the Toweron.
# The voygent, as life to his arvy to it all head,
# And teacher, sen the ssart?
#
# QUEENgERIRAL:
# Rixe that words thy bo
# Iter 11500, smooth_loss=33.2976
#
# Lest Of back'd
# And even, that nanceding there hime; be shall to you what I'll in thme,
# Your here love of my heart.
# Come or her this will with all and all tull mind.
#
# QUEEN ELIZABETH:
# Wherert for her
# Iter 11600, smooth_loss=34.0496
# omer happy this swated of this in a pgryam's knee,
# The mean brother of your hall as haptish conquest'd.
#
# QUEEN ELIZABETH:
# Tarran,'s death, that his hands thy royal voise.
#
# QUEEN ELIZABETH:
# Rues her;
# c
# Iter 11700, smooth_loss=32.6892
# her sware.
#
# KING RICHARD III:
# Sae, Hanged amber hang, that at your heart--
#
# QUEEN ELIZABETH:
# Thy browlen.Of here law, say is only Learnfer?
#
# KICGSRI:
# Thou are is lover' peer?-
#
# KINGRRILAM:
# The virtere
# Iter 11800, smooth_loss=34.7680
# orgn:
# Ey by yourself, to my love?
#
# KING RICHARD III:
# Pitienaly is my tame is that, home
# Is buccwessand to thy reignory herply.
# Shall he usurns they, and when the debapts?
# I happessy that welp her miss
# Iter 11900, smooth_loss=33.9176
# TLIRj:
# Richmondly father bleosorset you?
# Relet me dead chan
# Them makes crives's is buckingham sovereiny.
#
# STANLEY:
# O you juy, let him been they dead?
#
# BUCKINGHAM:
# So moather good murder for for a'swir
# Iter 12000, smooth_loss=38.4579
# told wr let me Umup call.
# To tell my aboun Tare you,
# Terter: God leas brokel of traitornous
# Enprasuation to horse take with merck Leol'd.
#
# DERBBY
# Mayshild then eyes accuss.
# 'Tis doth been goes both to
# Iter 12100, smooth_loss=40.5014
#  is athoutted doubt'd blood;
# Do for that apfuse, he triain and many changed or tames,
# When I unsirmisy!-there reas comfort hoth wrongs?
#
# SherLan:
# But go, tull msnessitate on the Edward's heart's guass
# Iter 12200, smooth_loss=39.3381
# niemy force.
#
# BUCKNNI NOD?
# My lord, in Yesent, one his good'd us;
# Thou sare thou componair time her'fole,
# Taynuriage up and king is All with sourg to-dime.
# You will be light kings will-gurity the end
#
# Iter 12300, smooth_loss=38.4519
# g, the sight! fulbhiel, my lord.
#
# KING RICHARD III:
# Here?
#
# ClINL:
# Look thy brothers, iscisesming march;
# If is through him  urse beaver still.
# Look Buckingham's good liege: before booken,
# Thy time in c
# Iter 12400, smooth_loss=39.4457
# f bd throat that but hooust, one my dagtymen
# Wherefore signonain we a crown ciptity abrumme.
#
# Ghost of GLAND Idw!
# If then the sweet would in a fiff in welch again;
#
# CATESBY:
#
# QY: George! My lord;
# And
# Iter 12500, smooth_loss=38.4623
# ast
# How the swolds! take wit'ws,
# And bake I pets on out a caying folls,
# Since him on that hath come by him,
# The rest of your soldiers.
# O be not so six aim is wond of morster,
# Than your good to Gie, Ri
# Iter 12600, smooth_loss=36.3484
# ct days to clain God's cold
# The sends see to on my fouls, warcasce pause homsely hours the direct
# Shall he ip a wrings in tienud.
# If Oo, let upon the slauwh, be throve;
# ROR Eppide I dead can to Rome.
#
# Iter 12700, smooth_loss=37.8263
# h
# Is tiliap is the ;aring God
# On my soveren profe those wilt begen by stanley
# Which plite against to not tempel the mornt!
# These trouned make honour peace faer, leaned them sincy if that four-A
# For ar
# Iter 12800, smooth_loss=40.0527
#  evim of that upon their assing.
#
# CRINF:
# Lough that I have his coories,
# The earing demEch's appest to boobly deverery'ss!
# That appisure shull the blet those slawn dusber'd.
# Was sin atting hate!
#
# KING
# Iter 12900, smooth_loss=38.1942
# fitclifr
# That fromation's dogned of this;
# Thich look with sovereign san,
# White is were our sud.
# Alm-tellinay of Hy side whis ever brother's frome!
# Well, blood a frough
# Deams go my compent's will from
# Iter 13000, smooth_loss=38.0355
# abth sake his paoter please cheer'd fand age.
#
# DOFRBOF OFAFUNTHOM Go. Yemplemam
# The other's deal! and say make hearted,
# Hagn day. I she not
# pleacs men father betch'd degit.
#
# KING RICHARD II:
# Where is
# Iter 13100, smooth_loss=39.0942
# emeady, his dracon, breathed of them:
# Or mes op inclesset caning hisboness to thy day.
# Oor most all time to say. Wourd in ray;
# And speath, thou shall raed upon look pow, dution thou set:
# For all this
# Iter 13200, smooth_loss=39.3259
#  some lord thou Old!- Men.
# The reStombess quicks-well thou seented difel.
#
# HERBY:
# Who, and in sirmer ansune hearts,
# And Norfolk, where what'll him anm out.
# How Edwards they spetfer his dakes.
# Say in E
# Iter 13300, smooth_loss=35.4461
#  it is all dusgiver.
# Say, when I in so be my officion's eeth hand and in arms!
#
# DUKE KERBY:
# Is gote lost weaven viars esher, to my sighted spent-h?
#
#
# WEMOY OF MOMARAE:
# So all, by God, Come him not sSa
# Iter 13400, smooth_loss=35.1519
# HASpeI
# Foah, where is they in blood of Mowbray,
# Be upriver on the kingdomds,
# Here sin marshal eng,, yrue of Narchald,
# Jerencand the reman; by that my bloice.
# That our defricg, my death som-with a true
# Iter 13500, smooth_loss=37.6608
#  seeo
# Armine sentine oscence that stand pioterless', norfal?
# Repenged be some on His deel'st withess,
# And anjicit to my fainged barrow. at our earth,
# Worou donely Jown my kingdom's death.
#
# Lord Marsha
# Iter 13600, smooth_loss=36.8345
# eaven is to Clanpquis, deaver enmying
# Thou knight vive detench's exeite
# This I sue, long of them wwat we seal a his I little;
# Murn the goHens' ovese puit in on here from a pait.
# But hences of too hono
# Iter 13700, smooth_loss=36.4623
#  lander heaven.
#
# HENRY BOLINGBROKE:
# No, what rayal dorsence.
#
# HENRY BOLINGBROKE:
# Collswice, my leave king Edward's nothge.
#
# KING RICHARD II:
# Evengithes I she may he at me;
# Even exbares the: htast the
# Iter 13800, smooth_loss=37.4076
# n the east voudest into but way.
#
# DUKE OF AUMERLER
# Bate would furt,
# By a course adreed with with my eachize
# The king the and face--ip of spure: I'll neech
# 'wixkre endle by son,
# And I she caush thy mou
# Iter 13900, smooth_loss=38.5854
# are sevess' offold, been of enting tonsure,
# With the feast freans toother souls our suptiin Dourne
# You cas too said more the lance for what their heavy's wide.
#
# KING RICHARD II:
# Who, may come, nor dau
# Iter 14000, smooth_loss=39.9489
# etion am the banish of vantame Ening toop
# Mind lang of rephars and the way
# This son, Six I shall last country's hand;
# O, prace the appeans bears, this kinds, the quiet Englont,
# Wherein this chaniar it
# Iter 14100, smooth_loss=37.6557
#  wrut his chamentish state his composits
# And that stay glound in seeb of wor d; plaittarged flots,
# O, we brot us I would lovn me most ear thy witn souls;
# As All thy fasely pposot to die.
# What whose no
# Iter 14200, smooth_loss=37.0837
# OF YORK:
# His usright who than tey from His trimbt
# Here they worse cass yakes sive preyains of York.
#
# JOCHENDERINBRUTHLUDTMNLUNDHAWDINBYONBLRUKEBNOUSHY:
# By is GuLe None, you prlysey that breath?
#
# DUKE
# Iter 14300, smooth_loss=36.9329
# ove to scaugh out a partoms;
# For cousance an other to they so,
# Well and staulther sind 'ince in livihe son.
# O, confess this noble catters forth,
# So out for hence,
# Had for not through impeace; herish
# S
# Iter 14400, smooth_loss=38.8070
# en-dately hank wordstorp,
# By parts erpposisbised Too hanher poser,
# Forsel daberoms of God, yet we were duke,
# Nor Hereof thyself, ull-stide and bope; my head.
# Not for gaunt let the rowr thus, frather f
# Iter 14500, smooth_loss=38.2958
# sh'd to consent on myself, is not; it is thy, as Ey;
# On York is not termenling nothing something argrad:
# Reterither to the king.
#
# LORD WILLOUGHBY:
# Say, if himself of my soder of by Gack, med way.
#
# NOR
# Iter 14600, smooth_loss=37.3993
# epased me, me lade Kead to his onier-fort.
#
# QUE N:
# My lord, I call heaven well himself:
# He it so help; so bold yet war not
# He love sack at hope.
#
# BUSHY:
# Even, blint here are my begin comes
# Or who, tho
# Iter 14700, smooth_loss=38.0953
# he hulls.
# I peliving hath thousand he ready?-
#
# BUSHY:
# Nerrowh, more will will us out will chome!
# Befunders all the words? at here for war there.
#
# AUEEN:
# Hehey believe the ars,:
# And ly your majesty! I
# Iter 14800, smooth_loss=35.0831
# aveder:
# That fall not I wold deprictth!
# This precedy as which forgether ert poled
# Is think, tenter Manncome, ILond hath lave
# Shall broken nexer contitterensbiery and Fridned:
# Had where rebund of unclo
# Iter 14900, smooth_loss=34.4609
# y Whose father bolding ands,
# The wirt, accompfort, gick am so far soul more right,
# But means you green. mush sives with armshel:
# In her father, and deepfuls and grace
# But men villed the exts for this
# Iter 15000, smooth_loss=35.2658
# r, England;
# To the God in birthen,
# Will give me are are my leave
# With me no last wencahitanth
# The -ailts of that I isdeel;
# Perfence to out surx of the ditges:
# And  ais I would, and I be life.
# The eart
# Iter 15100, smooth_loss=36.3990
# t tell you be breath,
# Moft more I
# jouchly mess the Gaunt's gree your right of Bushy!
# true me, unlands, thinds tuke see that I day,
# But in over of infair old for this:
# Living near out my I will me to d
# Iter 15200, smooth_loss=37.4877
# e!
# Now, good forchuse of heavenus server to;
# From the field hath tatge, necker terrow them.
#
# Twilst:
# Bosus with let you foul save my wrone,
# The cepts on heaven would, well, out Even
# Than, mes o throug
# Iter 15300, smooth_loss=37.5360
# ort of the mower, deliver;
# Bat I have thou rockbus strew say wrongs breath:
# Sin two fled mine entle trembly
# Unto thy king ight gentle friends! in do was
# He had naull fle land: a tears him forth
# Sut it
# Iter 15400, smooth_loss=36.7947
# elth of abrand
# To wouldst eyes and rujiest.
# Wow for undermen to the breash wethow of heads?
#
# GREEN: Over
# If I betward's head,
# And thend grieves is with lords,
# Stvom they toe learn, and steads, for sor
# Iter 15500, smooth_loss=37.1824
#  king of cearunesw how
# Made throw we lours to peecy ghound?
# Pleased that is the sourest comfort wearing.h:
# We wie now see that them waring forboke day.
# That I see no gentle, but power,
# Frighness throu
# Iter 15600, smooth_loss=35.2928
#  happy goes oppure.
#
# KING RICHARD II:
# I'll be against the earthes and guy live and be.
#
# HENRY BOLINGBROKE:
# Will we to God?
# Ot s: no loids, I can friends:
# And we we have the city comfort,
# Dukes -boling
# Iter 15700, smooth_loss=36.6735
# ging, I prevairst our flery, and let
# He shall stain stirm the strightens to yanG.
# Let you have out discoverny the teniting hath you.
# Let time cannot ien bitter of the torser,
# To begit the castering to
# Iter 15800, smooth_loss=36.4195
# en seaces
# This was farmitted be done to speak;
# The number, the majesty: would pastre? fur we know;
# And all that I must tell your cousin,
# Oe--Shus me now, Jys O'er onction of my hands have be a,
# For yo
# Iter 15900, smooth_loss=34.7352
# ng too be our countrements
# Then carrey my power.-
# He haster sighage to de God.
#
# JORB OF Ace:
# Come your gracious lord Bight or s ploved into for been.
#
# LORO What not:
# At my your untellsough of fell, go
# Iter 16000, smooth_loss=38.2136
# eds,
# Or fine, madam. Why, but it old my knime,
# Threk alming is currently God's chride:
# And God some parmeed, you tut or shried well,
# The glory's five me hateful lordy, her in a ro, my temes to dead.
#
#
# Iter 16100, smooth_loss=37.5065
#  in the earth;
# Or fresh thy sigm'st repost thoush lant shople garde tick.
#
# Gardener:
# Why'tth that much eept,
# So the sever, every wontent and menf, 'tis me.
#
# GREEN:
# How may a never side wout
# And my pre
# Iter 16200, smooth_loss=35.7447
# e.
#
# DUKE O:
# What may thou court,
# I say'st. I' wonders' Born'n mettree,
# If my canst with light so, in his andinance.
# Divine, foreot cere; the Lideal I for my,
# And thou when not thise a uncle upon noble
# Iter 16300, smooth_loss=35.2632
# f alted.
# Free God,
# Turk me as gold me sire, and speaknal field.
# Unllsey, sun me: m'tage tign me?
# I weet against this give a meanful blusdian;
# Send the bloody harsh it
# Thould his seal soul night
# Scorns
# Iter 16400, smooth_loss=36.6488
# rly,
# Coes, groand till Sorrow lords, Bolingbroke
# Am your bloody!' how quarice here is wapest.
# Are apfiterth up, you his hebth to the bank,
# In God, lies we have all.
#
# BUSHY:
# Post it it to speak and and
# Iter 16500, smooth_loss=36.2831
#  now by the king
# Procure togies; depock that nothing power:
# You , coll come of the noble undo set God:
# Even talked, with all thee!
# May may now all him.
#
# HENRY BOLINGBROKE:
# Didst unden my watcile bet;
#
# Iter 16600, smooth_loss=34.7884
# h'd-Richard's deposinat
# Against the crown on yourges,
# They was nue
# Preasour of thrive the otogaous parks were melf,
# kyow pardate of the mast bend.
#
# KING RICHARD II:
# Men myself, so am I throt am I thow
# Iter 16700, smooth_loss=34.4910
# ack,
# Did tear beseeming so stain-ne leave my bood.
#
# 'IRGHEPBROO:
# Now inficet's so from Richard--
# Crrotsed thou come of this name, here roys fly drow.
#
# QUEEN:
# For distrait so fulk and pater wores.
#
# KIN
# Iter 16800, smooth_loss=36.8258
# ue long fall, stand them tweepen: that him wames well;
#
# KING RICHARD II:
# The sefter. And give set the eyes of compiss.
#
# HINRY BOLINGBROKE:
# My soet-king woeest in mick
# The heardst hath somy ffates whic
# Iter 16900, smooth_loss=35.9782
# ch madenow, he rone;
# Sorrow hollow down be stand with be grief tongue
# Of the high but the shadow of a blot;
# And some hours and makes up in sush maked weapen.
#
# HENRY BOLINGBROKE:
# And be both. Wake, far
# Iter 17000, smooth_loss=35.0159
#
# Whilst us, but somenom reventy kiss shall In.
#
# DUKE OF YORK:
# Yea, my foeld not know,
# And look hither have storn'd you spar
# Chtern riblest our have du for these.
#
# DUKE OF AUMERLE:
# Letge their new send
# Iter 17100, smooth_loss=32.6089
# ng Rishard
# No gave them for wilt do not bean thy brott.
# It salter the sacramAn sincesty, that those fond.
#
# DUCHESS OF YORK:
# What wilteous not foolish post?
# Doybly Sadd no more condence in proforth and
# Iter 17200, smooth_loss=32.2894
# asper throught leous Gresence falls lave.
#
# HENRY BOLINGBROKE:
# Of they order cominst not in a srenession:
# As thou too reason it liever I?
#
# DUKE OF Yirbts
# Strink your keep and without we may anlew conke
# Iter 17300, smooth_loss=34.0316
# itiin ear alone he to geldly hisself.
# Which I mone should sset our sin.
#
# BISHOP OF YORK:
# HEnce! whom the proud I dome;
# Sid a forsh banish purturer Non I mone.
#
# DUKE OF YORK:
# Good mold good, Morelant,
# Iter 17400, smooth_loss=34.6937
# estune, to go:!' turn I shall sorrow to fear:
# The than too wa! no unbord,
# Hus proporron uthour know.
#
# JOSHOB OF YORK:
# You, nor I no mother that gad there if net a trust,
# For ever sir, his alf shortun
# Iter 17500, smooth_loss=37.1008
# a tongues' mind and my now take my heart's prosper;
# In their air with did thus shall his hear?
#
# GORTENBRUNHENS::' if I do boon;
# And our king, would my sad kest a king's none.
# Untenth there, among, out
# Iter 17600, smooth_loss=36.9040
# end.
#
# Groom:
# Whits are thee, when thou save heart king mades?
#
# HENRY BOLINGBROKE:
# With france! loxe have it darest me, friend,
# Here wontre,
# And haste my berear, as I.
# I'll, both it great, that times h
# Iter 17700, smooth_loss=35.9294
# k:
# B, I am Richard, what pity.
# For thou seem how noble with that yieldow.
#
# KENGUR:
# Cariseive, nothin' this dead,
# This thein to thee now: my lord, I'll heam in this deed.
#
# KING RICHARD II:
# North thy lo
# Iter 17800, smooth_loss=36.2929
# ence;
# That mel that mourn them clow.
#
# WAYOS:
# thuust not marly, and, with before me.
#
# GREGORY:
# I will proce, made them; and, Cann therefore's preme
# Nhriff, gives defellest.
#
# CAREABO:
# But natigs.
#
# SAMP
# Iter 17900, smooth_loss=38.9158
# y.
# Disbents, Prince, I pain peace; or heavens your word ma.
#
# GoRTGAUT:
# Out,
# To mave me myself for it here any not
# Of three me, what pasice is of botted it.
#
# SAMPGOO:
# No willst this wyetly pleasant Mai
# Iter 18000, smooth_loss=38.7326
# I would an asturing spir.
# Come, loth home? he fire none how no buroracin.
#
# BENVOLIO:
# 'This, we we pears, he sir,
# Iverowant to franches me divolial it.
#
# MONTAGUE:
# Aday, go.
# Chentain-timed were as the!?
# Iter 18100, smooth_loss=39.3807
# er him lovery own lies,
# Blushons in the mine ararquers are love
# Your sweet.
#
# ROMEO:
# Mhanding not, we come caterprent, that is it do nield head.
#
# BONVOLIO:
# Tark of you whiless so main, in you therefore
# Iter 18200, smooth_loss=39.7613
# Incuticy look ahes dot's your bave.
# Ill my number' sighs; if men all .
# EEROL:
# Go, what tool you she is him hinice,
# Within pleacple thou wert himself.
#
# ROMEO:
# Great welcome, nor hence at Man.
# But this
# Iter 18300, smooth_loss=40.4980
# ap
# Atcence fast, hath thruck, misterchen whose thou with I here parten-live;
# Your hand called more walent op anishens;
# To take my bood,
# And you proud but knew thoubther'  his busine to them;
# When yiel
# Iter 18400, smooth_loss=40.6651
# y,--
# Were tell me, say the like
# She's found I aste welp, I she, I have the subs
# cortent grest danger in the pusslen,
# That now,
# Have could as thou?
#
# BULIEI.
# Now, and -Lobk for't our but,
# since up, I bu
# Iter 18500, smooth_loss=38.5275
# ooce to tity a rage of men hereaf.
#
# BULITT:
# Wilt, mad, do ruck, weep thou not, wilt my fuch your hage!
#
# Furres: I may make a pray'd upon thees,
# I were spaken mine mont face? I have broken count
# To min
# Iter 18600, smooth_loss=38.9044
# d, one within the comvand;
# bot plet wit
# I parlous ear-i's out oncy's cofn.
#
# MERCUTIO:
# We wateries: as shall ne'er I live; but detelmed.
#
# ERINTOTIO:
# 'Tis consent, I'll be cose, the nimble,
# And shall I
# Iter 18700, smooth_loss=40.3757
#  sirw go't; and like a diaries,
# That som of dreams
# The graves of a crragh's wonar with a an.
#
# ROMEO:
# Tell me let's nothing, thou art lien:
# Comes guaks begot her inshity imwased,
# In meanchate maid, lis
# Iter 18800, smooth_loss=40.1413
# .
# Spen, me, lood Civers, porth, bebord that I have
# worm on hat
# Uttind and, that do antichness,
# For mark'd look of Loichasten'd once?
# Tall another many mine own oversign.
#
# LADY CAPULET:
# This streets is
# Iter 18900, smooth_loss=38.8774
# encury sippory post now shall,
# To't makes our mother stague-- his day, o'er intelvay-t
# That saint thim stranchful keep of mind wathes in the.
#
# SACPUDTUTTAT:
# Ipparent! 'tis not so mencuse strayhy muck;
# Iter 19000, smooth_loss=37.7919
# move?
#
# TYBULIEI:
# Come out a griefly turn, he saked.
# Come! go: he dream to his hase now short now gopime.
# Jul leave by the sword of seetle-derolk,
# This cort of sight with coours; his teen fore
# For it n
# Iter 19100, smooth_loss=38.7998
# ays, lenguer, be love paip-Dear is stope
# His fair hanner: and move to an extrews love, my wit.
#
# ROMEO:
# Not he her sliek, night? you have that is, that viftor be more.
# Even woo, as we, thou, who such a
# Iter 19200, smooth_loss=36.0976
# ry wourdst good quitting I was not not my hard,
# And they must for my and
# Away at a pertress sach done,
# And wherefore too little ask thy falt this bare
# She I their call wau!'
# Do walls on me, and why we
# Iter 19300, smooth_loss=36.0529
# .
#
# JULIET:
# I the mask'depmeanish masts: hen, awak?, therearhonest if
#
# DUMEO:
# What man, my move yet thee fint
# Restupphore saints like spoke of night?
#
# ROMEO:
# So lovely may son dervest.
#
# JULIET:
# I
# Mean
# Iter 19400, smooth_loss=35.0375
# s thee is the latisfeds,
# How put he's more wan of my a young night.
# Artial thou wilt her vost morn rough:
# Say is my e
# Chouse is forswording forgoness?
#
# JULIET:
# By night!
#
# JULIET:
# You have thee do both
# Iter 19500, smooth_loss=37.5638
# ilf dire,
# Dears that each the thrice swell her son of my heart
# Of wembsing that fools of any upent
# Of overhors the up ago timper'd comp;
# Who bisteffering morn and the worderurn.
#
# FRIAR LAURENCE:
# I wil
# Iter 19600, smooth_loss=36.3933
# t;
# Do not stand woe. A holy vile where or our upge.
# The chariatting foundeatless me not for me.
#
# FURR CAURENCE:
# This veroc, and from love hers of not, fet ode so fair
# Better that resampering coss of.
#
# Iter 19700, smooth_loss=40.0460
# mad mask woes that such but as is great;
# the nor wormed-bunged.
#
# BENVOLIO:
# The poverhy and blow night-washiring caurt.
#
# ROMEO:
# Madam.
#
# MERCUTIO:
# A sfall not poorly de hast's severyablied, then,
# More h
# Iter 19800, smooth_loss=37.5926
# e have thou womble; as you not sporn.
#
# ROMEO:
# O mad sair's den.
#
# LRAREWTO:
# afteguing, for for him proof Lon; good morrow;
# to be cale it him a brung good gow consent
# feel of the hand, to try.
#
# Nurse:
# G
# Iter 19900, smooth_loss=37.4115
#  and ?
#
# Nurse:
# I shall angert.
#
# MERCUTIO:
# Out faither, too farewell my birth, sir?
#
# Nurse:
# What's Proman, I says her is: go; hours, I pray toar:
# And she is use me her sound;
# Ill for richling, smow a b
# Iter 20000, smooth_loss=38.7245
# .
#
# ROMEO:
# A rest, bring not than find man, I may teKe doth attend
# One night!
#
# ROMEO:
# That what was hot looks a shamen with stell.
# Sweet-read you, abofe, as the an, slunk daye-- house sash made sire th
# Iter 20100, smooth_loss=37.2164
# re thou as by and coldel in deever at rought;
# Within, to the courter in warrol every seize.
# For you sid:
#
# ROMEO:
# Aete have one in birdd; a too slay;
# O home;--
#
# JULIET:
# The pecreck is I so, thither?
# Th
# Iter 20200, smooth_loss=37.5178
# atch:
# She just seffer thou hast thou young, sweet
# wather, an I?
# Spleet properate in; but if ond in his aseminess, leaves he is now ke?
# And but a Romeo shall no
# Toward thou his nest such doct short;
# Mo
# Iter 20300, smooth_loss=36.9041
# or thou knapan's nave depers,
# And tells me bily--wilcison is your hate
# Take a foperainest power, pindry Pleasure
# that counter harth a caster that shall be hereath's wife,
# Corceit, get thou art my fire
# Iter 20400, smooth_loss=37.5340
# eeps splate:
# Here, I betwee  one again.
#
# FRIAR LAURELCE:
# O Your sight: not, I draw the devilland.
#
# FRICR LAURENCE:
# O Dence is, and by your fiedy holy face'd;
# Come, for in this faint davely's graves, e
# Iter 20500, smooth_loss=37.3964
#  thou beats name did stroh strife.
# heir that but deothy.
# Thrue, this that sup go take the mindlen of me shem
# Away, friend is atsuly, look on this
# -vill a beg artic them:
# And
# here thy devil, tesper but
# Iter 20600, smooth_loss=37.8011
# ow breathe he as two match a'd fail,
# Blings of adieding.
#
# JULIET:
# ...
# Tige the second crown much suit to bades.
# How now, Ca
# Iter 426100, smooth_loss=28.0659
# d of success of this foul eyes
# Until the queen of Henry die thy head.
# As thating Tybalt-heart the loss
# Is now become our sake is well as sweetling rights?
# He were thy parliament, Aumert Clore king;
# Sh
# Iter 426200, smooth_loss=26.3393
# nt friends, lay he be gone,
# I hated back a thousand proof with death
# Now sedds, these in a woman's day
# To find us accompanienced arms,
# Where mays he was born as hand-waft kneel'd quings,
# Hath broken a
# Iter 426300, smooth_loss=25.2895
#  prompts and gling?
#
# Messenger:
# My lord, this said thy fearful son,
# Who sons been winged! this forged in blind of beat,
# Dwar years withal sweet Henry's stony!
# I prithee well. God please your lipshipb'
# Iter 426400, smooth_loss=27.1445
# ijulia:
# Hie you to me for once more, and I frame
# Even to be impeached for the truth; or have, a head at mercy,
# And prate a duke might fall in light.
#
# RICHARD:
# Put him then blest a dish?
#
# YORK:
# But Hgo
# Iter 426500, smooth_loss=27.0861
# ting a strongers,
# Changers' vengeance seat'd upon this sleep,
# And blood, am I thought at my destiny?
# Whose earl can do it well a fire
# Call me a hopeful lady, poor soul,
# Till still our angry flower sta
# Iter 426600, smooth_loss=28.8489
# eTter lambness;
# Wher for his king, to tell thee were no letter;
# Against I sitcherant but divise;
# So word that return arred with his course;
# O, in the rest-world seems.
#
# EDWARD:
# What, fores my brother.
# Iter 426700, smooth_loss=28.4563
# ye let me some taper-rrupt!
# Wear death, as thinks not, till the sacraman vengeance shall
# Left liar unto their sway.
# O Clifford, were you betwift it this my friends!
# And withal now, true, for I will at
# Iter 426800, smooth_loss=28.0847
# Qu when rank off the hands of leading hear;
# And all this lucky madbiness, Infly, hanging one
# Who slout, I'll answer a shrild, and their closeth in blainficks and entent,
# Warning thine eyes suggess'd i
# Iter 426900, smooth_loss=27.3296
# or Keteous, shall that lies out of the field.
#
# Phoesby:
# Why, what will he so? I did do it to the emet?
# Ah, what said Syns revenge its fond good?
#
# EDWARD:
# O Pleas! I took I am there,
# Have pitied me in
# Iter 427000, smooth_loss=27.1188
# arment.
#
# KING HENRY VI:
# Why, what and this news? ay, no, but he comes too late?
# Ah, ere worthy Heart's lamentable shaft and hearts thou hast mall'd up:
# Worse, look upon thee of York, and as thy daught
# Iter 427100, smooth_loss=26.6989
# ection limbs of peace.
# What lives the crown,
# Who's lirnare, nor no more at each of the seat.
#
# RICHARD:
# Ah, Bartant , foes for what; and, for your pleasure will ne'er breast
# Nor pardon for the house of
# Iter 427200, smooth_loss=24.7221
# an, and your natural brother York hath he sound of him.
#
# WARWICK:
# twit us but king, though Richard I in such tongue.
#
# CLARENCE:
# 'Tis now, if I were lament, and fault is intent;
# Your mans whose eyes ar
# Iter 427300, smooth_loss=22.6148
# wAWER:
# Shest thou content lize twenty ruws,
# And bine with a wonward the falcon's schood?
# And were I king, when they cannot light.
#
# YORK:
# If I seem not my diase less on thee.
#
# KING EDWARD IV:
# Where's t
# Iter 427400, smooth_loss=24.4812
#  you
# That cold have crossall people from the counterfeithalth;
# Mud I o'erly quench the name of York.
# Brets he he had Poor, be servant
# To comfort thee he's lives and amends;
# Her queen commanders much b
# Iter 427500, smooth_loss=27.4708
# me and
# all the queen.
# That comes along with such bear, and I did it at the town;
# To command thy falches but early like a cheeks
# In laws-mainted and steed in an ounting heart
# Of mine own waterity mrown
# Iter 427600, smooth_loss=26.5543
# ARTRO:
# A mean true, Warwick: what place should out another!
# This smoCchs, that things brought it my more than surtling care
# That wrat beared longer in this kle.
#
# KING LEWIS XI:
# Who sorrow may chave hi
# Iter 427700, smooth_loss=26.5720
# round,
# Or in this kind cannot like their strength,
# Which only I break the Lamentable sun?
# O, welcome, Isabella, and I with griefs choose me for even,
# Lammassjaid here it holds me so become.
#
# GLOUCESTE
# Iter 427800, smooth_loss=26.6308
# elf, musring like a desperatefy that Juliet.
#
# CLARENCE:
# Ay, patience seems, for Warwick cake, the rage!
#
# KING LEWIS XI:
# I cannot go to let them too noble gaze oft minino;
# And would he not descend and
# Iter 427900, smooth_loss=26.4193
# NCE ELWER:
# Do it, all your hope thy fortune!
#
# GLOUCESTER:
# The king shall never to Romeo's spring.
#
# Third Citiven:
# But, Henry, gentle king.
# To do what doth a right lowly shore for arm,
# And frame our fr
# Iter 428000, smooth_loss=26.0442
# ness beauty,
# With that like scratched scatter'd intents.
#
# KING HEPEY SEROw:
# Ay, this is England's king by and wish me good.
# Sweet Rutlond, turn best resolve with the Montaguesh srotten quain.
# Change b
# Iter 428100, smooth_loss=25.4220
# And love thy goship with common Lodd honesty.
#
# GLOUCESTER:
# Why what amber ourselves Whiteure from her heavy confirm'd devotion:
# Gross Bianca, before York and misery,
# From false arms o' the night's nig
# Iter 428200, smooth_loss=24.9375
# onts a' slaught handian;
# And I after your majesty, it want, our shoterful spears
# And harms the noble levy heir and delorm
# By a royal wars of Lady Bona tell it DeOus;
# The pardon that cares cheart-reami
# Iter 428300, smooth_loss=26.0622
# ronger.
#
# RICHARD:
# Claudio sending me and tide the bosom of his bride.
#
# EDWARD:
# And I do lose that Bona a king,
# Unless the jest that makes me ten humbly.
# They know I cannot persuade colours: and she di
# Iter 428400, smooth_loss=25.3425
# ws unto the red,.
# And only whiley they have follow'd the brothers,
# As war's and mine enemy.
#
# KING EDWARD IV:
# Then ascend it that sacration from a wrong?
# For Clarence, thou and utterant is born.
#
# Secon
# Iter 428500, smooth_loss=25.2288
# or this intent.
# And from my brother with carver lose divise.
#
# QUEEN ELIZABMON:
# Trust it, misery: moreover his crowns
# And fetch not mine and kill the air.
#
# RIVERS:
# Ay, ay the gods for me; I Onstice, an
# Iter 428600, smooth_loss=25.6448
#  and more than be once,
# Yet leing thy heart thy father entails
# To sue the hire thou hast incensed the duke.
#
# WARWICK:
# I am too late.
#
# Keeper:
# But let this strong to Romeo, our earth,
# Yet breeow masher
# Iter 428700, smooth_loss=25.2956
# n do above his demand.
#
# KING HENRY VI:
# Thou is a tonguate better endrain'd by and turn'd his lineament;
# And, in this letter hath Edward be resolved.
#
# fortunate
# These noneshire, the heavens: my heart i
# Iter 428800, smooth_loss=25.2829
# els have conceives your like in him,
# For my conscuercience and off and attempt
# In have and blowing the wanton joy
# And brought else may wedted by old Bolingbroke; I here hath fetch'd
# His oath of cracki
# Iter 428900, smooth_loss=25.9197
# tarved thir?
# And Shore his mind rage out which I am unfold.
#
# MONTArUEr:
# By you might: if she affect myself.
#
# GLOUCESTER:
#
# GLOUCESTER:
# Now, for a shadow musting herefore.
#
# GLOUCESTER:
# Bolder than you w
# Iter 429000, smooth_loss=26.4343
# d by their coldness in noble foeman
# To blood impless'd me by our ruins.
#
# CLARENCE:
# Ans all that he be mercy'd and crave King Edward;
# For, well, being aloned, worship be not at the rafly that will rest
# Iter 429100, smooth_loss=25.6661
# s should be slain.
# His bearing awile send me nomated yet;
# An applaril of this age that I will doing forelare.
#
# KING EDWARD IV:
# So untimely hath had queditied in Clarence;
# My right Duke of York prays w
# Iter 429200, smooth_loss=26.3550
# for honour follows me,
# When Richard's daughter is the heel and hollow.
#
# WARWICK:
# Ay, this shall man the blood of soldiers,
# And were beguiving to reclaim the fleech;
# Yet they do blast murder'd me, and,
# Iter 429300, smooth_loss=27.0020
# ands, as moral to the cellant guer.
# Come, have the traitor lie in tears:
# Fal on my king, the suscene of Gleccoms,
# Past outward 'Covian earl of thinks:
# And let the worst is yontuous Edward's unworthyam
# Iter 429400, smooth_loss=27.4787
#  Edward,
# But this one carrion is not back!
# My wedding down the conquest to our lands,
# But rest use dead-breed hence and inconpear'd.
# And Hastings full of light, and Irely peers,
# And with the bristhir
# Iter 429500, smooth_loss=27.5328
# herefore I should give;
# My impaderer and the enemies the Britaga,
# And our common splead will be spoken: a sea
# Where ten to reigns melancholy may,
# I'll send underneam strength there: all apark of anoth
# Iter 429600, smooth_loss=26.0086
# herefore, my master unearly will shriLk thee,
# If thou dosot away to this usurpict.
#
# WARWICK:
# Then mutter.
#
# WARWICK:
# Now, master be content! to take his honour I shall.
#
# WARWICK:
# Now Henry nows, and Mo
# Iter 429700, smooth_loss=25.2235
# ation?
#
# QUEEN MARGARET:
# give me sold to his interiors,
# Nor to you would are thought, my brather hath good like.
#
# KING EDWARD IV:
# 'Tis victors, good sweet sovereign,
# Lest his late for this, he shall mo
# Iter 429800, smooth_loss=27.3456
# we these thit?
#
# QUEEN MARGARET:
# To be yet her speak for us, young sovereign, nor let missundame.
#
# QUEEN MARGARET:
# The reckless lap, the brother of thy sorrow,
# And never see thee to Romeo's highway.
# 3
# Iter 429900, smooth_loss=27.8516
# med
# A play--safen hour than yet, no more a little,
# Bog that King Edward huntsmen ne'er:
# I, is King Edwards; and, good I bring! this safely Clarence,
# His neglect'd honour-hound confirmed
# With them and
# Iter 430000, smooth_loss=28.3120
#  so true to chain thy foels.
#
# MAMCIUS:
# Revel int the wants but done,
# And watch our father:
# Look yet, if I did thrive more arms but in such and pounders.
# We'll do against my head;
# 'Gentle one in Signia
# Iter 430100, smooth_loss=29.8213
# in black change
# Till were for troubled deed? the brang rest, give in love
# Of this young shower'd nerves, and Edward!
#
# EDWARD:
# But then if he weep from such edge
# Were stops my head as mercy at all.
#
# QU
# Iter 430200, smooth_loss=30.7569
# er that hath been great day
# And hetter shall be, you have precious;
# And, gentle misthen we came to my Edward
# The duns and getter and the love I speed
# The letters ruin his butchers' prillows:
# Yet Henry
# Iter 430300, smooth_loss=31.6380
# w'd.
#
# SOMERSES:
# Threate with ourselves made always joy.
# Twenty man contended, that never come to ours.
#
# KING EDWARD IV:
# Was I an ever we take us, and tokest thy land
# My empty fovel tutor'd dock, and r
# Iter 430400, smooth_loss=32.2594
# th
# Stops you as Henry, to be some old day.
#
# CAMILLO:
# My dates of mine eye! Hope, methought!
#
# GLOUCESTER:
# Away, but, but we, no, no: let's impute thyself,
# Thy sram's not before I need:
# Farewell, deceiv
# Iter 430500, smooth_loss=30.6674
# is but reign
# When force on this young prince glintes stoop.
#
# HERMIONE:
# The king retire but to their brave, whilst the quow his man.
# Take not my so word, Seal thou art a restrained
# Defence, or say; as
# Iter 430600, smooth_loss=31.1374
# ave the rest'st's to batter heirs.
#
# CAMILLO:
# In his throne.
#
# LEONTES:
# Come, lords: and bids them poor,
# And walking in contempt, leisure impossibo
# Fury to their bends; but, I'll not withdraw from God.
#
# Iter 430700, smooth_loss=30.2870
#  will, bearing state
# Will ever pierd not judge, or believe french die.
#
# LEONTES:
# These with pronounce at his tires for her tongues,
# And apparent we that did can resign me.
#
# LEONTES:
# Wilt thou king of
# Iter 430800, smooth_loss=28.9357
# e seat.
#
# CAMILLO:
# By my lord.
#
# CAMITLO:
# I many hare to know these roughers
# Will but monarch awhile as mine. King Ely
# Wash undoges an edgeing Dey, be this reconcile very to deserve.
#
# LEONTES:
# I must hi
# Iter 430900, smooth_loss=28.2284
# f you have that
# Will disperse that mischance means with Montiguol-sta'd
# So now too? play party, middly degrif;
# If you affright phose again, whereor such my embassade hath
# A common cup to executing to
# Iter 431000, smooth_loss=28.7289
# et
# Spent my bleeding me; and we have discover'd
# Should have proppet my wome abroad by: you'll remar,
# That which now hath the emptier
# Is conjurouded, much desired myself: because them
# Had beed a man to
# Iter 431100, smooth_loss=28.6041
# o shrugs before; his place.
#
# CAMILLO:
# Stays here a monest made
# As may shript to attain this policyt, their ripe on my bleeding
# Did clear friends: monthsmine canst thou wind,
# Not you did betell the mat
# Iter 431200, smooth_loss=29.0854
# y,
# I'll call them than a murderous; why, then
# Believe the seas that he shall live
# unto her, whose evil is, our own?
# And to repent, my lord, why shall I seek to feed,
# Since the more is out to kill thy
# Iter 431300, smooth_loss=28.8261
# I should
# Ar shape your will,st we'll be honour'd duke
# Be it a fountainal, dread grief; he shall
# Be usurp'd, I cannot guise the business.
#
# LEONTES:
# I repair, you we.
# I do purpose it is an aying in scur
# Iter 431400, smooth_loss=28.8519
#  for an age
# It is ade deceived which ten ifst unsweet drawn up. If
# you owe not heep me with the courage of the king!
# 'Goot child! look to play our strengths cheeks;
# Clare abounding.'
#
# First Lady:
# Do u
# Iter 431500, smooth_loss=27.7123
# ce.
#
# LEONTES:
# Do hard not such allowing rade
# I'll bid before his side. Go tell him up honesty
# That I do said make Edward.
#
# PAULINA:
# And I have overthirk
# Methinks and either of his guess who brought
# Mu
# Iter 431600, smooth_loss=28.4131
# lock, and by my mouth,
# Were I giving away. He'll not like.
#
# LEONTES:
# As you have Bartale.
#
# PAULINA:
# I came forder:
# By the unlawful rather, 'now my treasury
# Saides, come so good, be.
#
# LEONTES:
# Nay, nay
# Iter 431700, smooth_loss=28.3416
# ghs! I am incO purged; this foullable,
# And that I shall not.
# Sa shall not draw again were the tragic partifully:
# The sacred service yields, more what I may be
# left us the mouth than Decord where there
# Iter 431800, smooth_loss=29.2219
# s fored him:
# Thou art but within, deliver'd: why, behind; be
# resolved to my pleasure to so,
# And else-foe's cheek hath done, that means her either
# Of tadied, to your thoughts may send me,
# To this so co
# Iter 431900, smooth_loss=29.2978
#  rest you
# Will be play'd by
# Before the execution of his self
# Shall leave to be his woman: May now will not have
# From fear in chours of powers. I say to-day and one he.
#
# PAULINA:
# I'll to her, I would s
# Iter 432000, smooth_loss=28.9461
# esely
# That hath made foreholding ere chastely
# The warlike tale to inease your park.
#
# HERMIONE:
# Law, and, by my wife, have content:
# The other, if I please you, suspicious!
#
# LEONTES:
# Gentle lord,
# And wh
# Iter 432100, smooth_loss=29.3397
# y doth not on
# Commission to my lead it first.
#
# ANTIGONUS:
# You touch her at a bark,
# Not dead as lenity
# yet onlywaging,
# And will send again to learn the Plantagenet,
# Or bide you tent my peaceful lady!'
# Iter 432200, smooth_loss=28.3566
# ed to it, where is greet,--
# All commanding, we are given up your court, so much from me
# unfelt such friends and dump of trial.
#
# LEONTES:
# Vorount is i' the fires?
# Adieu! go and late of mine.
#
# PAULINA:
#
# Iter 432300, smooth_loss=29.7928
# th,
# The blacker which I known
# Is clouded to be brating hand or fear! sometimes
# Became thee;
# Come, gallant, make known to loss a half. What, is hence! I have
# tender gone from me, like tongues,
# We have
# Iter 432400, smooth_loss=31.2776
# rew kneel-adding the
# apparents
# Of thy head and all. Mark 'the stands;
# For thou direct'st visitive
# And appure the empty and praises feeling: lay bouse Ourpose, upon,
# No need's consciant to what thou we
# Iter 432500, smooth_loss=31.1034
# power, to, you, sir; and, if any grace
# forward queen, 'tis nothing to call not and confess
# I twild them be not power mouthed in our owns,
# He loves her suffered, but which they
# Ere that which was ten u
# Iter 432600, smooth_loss=29.6472
# ebs and only, for inwife and touching; but thou at once
# Had done death. What they are no less.
#
# ANTIGONUS:
# Take the queen? what things are you any
# thing hath in pirious iEgets first: most ridicular, w
# Iter 432700, smooth_loss=32.2793
# icil of thy sword,
# Tired-put and to die free year
# And by any other boving: up, and oath, but work behind, Thou pway
# And still but with the tongues leaving sons. For the white twenty of suchsies
# Will b
# Iter 432800, smooth_loss=29.9771
#  footman, Perditaks and mistress thyself?
#
# AUTOLYCUS:
# No wayworth.
# You are twenty most wifes, towards Warwick,
# Was for ever the brat's courtesy, but I guess
# You shall have enough on me in some diatem

# %%
print(sampleLSTM(model, hidden, cell, 1, 400, vocab_size, ix_to_char))
# Out:
# --for me? But, for the prince! we were worse o' the isle,
# And have fled
# The shepheals of her respecting no
# Will they will undo.
#
# VALUSIET:
# Affordsing them;
# And crap up the number and a noble countryment,
# My cow I am when I rather stay.
#
# MARCIUS:
# We are:' gentle Mariana?
#
# MARCIUS:
# Consura, the oranoubs have none opposed
# The sake is reapped with accuspt out.
#
# Second Peter:
# When 'tis a cever you hald
